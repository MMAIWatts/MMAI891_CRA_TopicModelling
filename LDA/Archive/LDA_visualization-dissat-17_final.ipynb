# %%
from gensim import corpora
from parameters import *
from NLP_preprocessing import *
from LDA_model import *
from utils import read_data

import warnings
warnings.filterwarnings('ignore')


#read dataset, only keep desired text column and rename it
data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE)
cleaned_text = process_text_col(data, text_col = RENAMED_TEXT_COL)  # processed Text Data

# Create Dictionary
id2word = corpora.Dictionary(cleaned_text)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in cleaned_text]

# %%
# coherence_vs_topics(texts= cleaned_text,corpus = corpus, dictionary = id2word ,min_number_topics = 4, max_number_topics = 20)

# from IPython.display import Image
# Image('out/coherence_Topics_plot.png')

# %%
NUM_TOPICS = 17
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
#17 topics
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
# df_dominant_topic.head()

df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# 4.0     1640
# 15.0     946
# 8.0      486
# 0.0      399
# 10.0     322
# 6.0      280
# 12.0      96
# Name: Dominant_Topic, dtype: int64

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 20               0.0              0.0588
# 77               0.0              0.0588
# 83               0.0              0.0588
# 96               0.0              0.0588
# 112              0.0              0.0588
# ...              ...                 ...
# 4074             0.0              0.0588
# 4077             0.0              0.0588
# 4133             0.0              0.0588
# 4162             0.0              0.0588
# 4163             0.0              0.0588
#
#                                                                           Keywords  \
# 20    receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 77    receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 83    receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 96    receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 112   receive, answer, owe, contact, refund, money, explanation, list, hold, email
# ...                                                                            ...
# 4074  receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 4077  receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 4133  receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 4162  receive, answer, owe, contact, refund, money, explanation, list, hold, email
# 4163  receive, answer, owe, contact, refund, money, explanation, list, hold, email
#
#                                                                                           Text
# 20                                  [system, maintenance, prevent, fulfilment, purpose, visit]
# 77                                                     [poor, support, issue, clear, guidance]
# 83                                                                    [view, contribute, resp]
# 96                                                                [tfsa_contribution, reflect]
# 112                                             [tfsa_contribution_room, reflect, transaction]
# ...                                                                                        ...
# 4074                                                         [explain, clearly, reason, owing]
# 4077                                                                                    [mind]
# 4133                                                                        [upload_documents]
# 4162  [administrative, nightmare, employed, manage, constantly, reassess, reassess, fix, pass]
# 4163                                                           [correct, misspelling, mistake]
#
# [165 rows x 4 columns]

# %%
# df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) < 0.18]

# %%
#Wordcloud 
get_wordcloud_LDA(ldamodel = lda_model, num_topics = NUM_TOPICS)

# %%
# word_count_topic(ldamodel = lda_model, num_topics = NUM_TOPICS , texts = cleaned_text)

# %%
# sentences_chart(ldamodel=lda_model, corpus=corpus, start = 0, end = 14)

# %%
# Plot_topic_dist(ldamodel= lda_model, num_topics = NUM_TOPICS, corpus = corpus)

# %%
# tsne_plot(ldamodel = lda_model, corpus = corpus,num_topics = NUM_TOPICS , Keep_well_separated_pcnt = 0.35)

# %%
# pyldavis_plot(ldamodel = lda_model ,corpus = corpus,  mds = "tsne")

# %%
def top3_topics_per_document(ldamodel, corpus):
    topics_top3 = []

    for i, corp in enumerate(corpus):
        topic_percs, wordid_topics, wordid_phivalues = ldamodel[corp]
        dominant_topic = sorted(topic_percs, key=lambda x: x[1], reverse=True)[0][0]
        try:
            topic2 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[1][0]
        except:
            topic2 = None        
        try:
            topic3 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[2][0]
        except:
            topic3 = None
        topics_top3.append((i, dominant_topic , topic2, topic3 ))       


    df = pd.DataFrame(topics_top3, columns = ['Document_Id', 'Dominant_Topic', 'Second_Topic', 'Third_Topic'])
    
    return df

# %%
top3_topics = top3_topics_per_document(ldamodel = lda_model, corpus = corpus)

# %%
len(top3_topics)
# Out:
# 4169

# %%
len(data)
# Out:
# 4169

# %%
cols = ['Quarter','Submitted date','What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.','Approximately how often do you visit My Account?',
 "Overall how satisfied were you with today's experience?", 'Which option did you choose to login to My Account?', 'Did/do you need to call the CRA to complete your visit/transaction today?',
 'Are you:', 'I live in...' ,
 'What is the highest level of education you have completed?', 'Would you be willing to indicate in which of the following age categories you belong?',
'What language do you speak most often at home?', 'Which of the following categories best describes your current employment status?', 'Which of the following categories best represents your most recent annual household income, before taxes?', 
'Are you an Aboriginal person?', 'Are you a person with a disability?', 'Are you a member of a visible minority group?', 'From what type of device did you access My Account today?']

def read_data_cols(in_dir, filename, text_col, renamed_text_col, text_language = 'EN' , other_cols = cols):
    assert len(renamed_text_col) > 0
    df = pd.read_csv(os.path.join(in_dir, filename))
    df.rename(columns={text_col: renamed_text_col}, inplace=True)
    columns = [renamed_text_col] + cols
    if text_language == 'EN':
        # filter english only and not null rows
        df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'EN'),
                    columns]
#     elif text_language == 'FR':
#         df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'FR'),
#                     [renamed_text_col]]
#     elif text_language == 'ALL':
#         df = df.loc[~df[renamed_text_col].isna(), [renamed_text_col]]

    else:
        raise ValueError

    df = df.reset_index()

    return df

# %%
org_data = read_data_cols(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE , other_cols = cols)

# %%
org_data.shape
# Out:
# (4169, 20)

# %%
merged = pd.concat([org_data, df_dominant_topic, top3_topics.loc[:, [ 'Second_Topic', 'Third_Topic']]], axis=1 , ignore_index = False)
merged.head()
# Out:
#    index  \
# 0     17
# 1     36
# 2     56
# 3     58
# 4     72
#
#                                                                                 dissatisfaction_reason  \
# 0  couldn't find my gst assessment  it logged me out/timed out during setup/printed a blank page/sa...
# 1                  more dissatisfied by the cra and the time table for my reassesment of my 2016 taxes
# 2  This site is not user friendly at all, specially for people, who are not accustomed to the use o...
# 3                                               The option to login on the canada.ca site feels hidden
# 4  could not access my spouse (my wife account) yet I am her representative, We are living in Czech...
#
#   Quarter Submitted date  \
# 0      Q4       1/4/2018
# 1      Q4       1/4/2018
# 2      Q4       1/5/2018
# 3      Q4       1/5/2018
# 4      Q4       1/5/2018
#
#   What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.  \
# 0                                                         Proof of income statement (option "C" print)
# 1                                                                                          Tax returns
# 2                                                                                          Tax returns
# 3                                                                                          Online mail
# 4                                                                                          Tax returns
#
#   Approximately how often do you visit My Account?  \
# 0                          This was my first visit
# 1                           Once per month or more
# 2                           Once per month or more
# 3                           Once or twice per year
# 4                         Once every 2 to 3 months
#
#   Overall how satisfied were you with today's experience?  \
# 0                                       Very dissatisfied
# 1                                       Very dissatisfied
# 2                                   Somewhat dissatisfied
# 3                                   Somewhat dissatisfied
# 4                                       Very dissatisfied
#
#   Which option did you choose to login to My Account?  \
# 0                            CRA user ID and password
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   Did/do you need to call the CRA to complete your visit/transaction today?  \
# 0                                                                       Yes
# 1                                                                       Yes
# 2                                                                        No
# 3                                                                        No
# 4                                                                        No
#
#   Are you:  ... Are you an Aboriginal person?  \
# 0     Male  ...                            No
# 1     Male  ...                            No
# 2     Male  ...                            No
# 3     Male  ...                            No
# 4     Male  ...                            No
#
#   Are you a person with a disability?  \
# 0                                 Yes
# 1                                  No
# 2                   Prefer not to say
# 3                                  No
# 4                                 Yes
#
#   Are you a member of a visible minority group?  \
# 0                                            No
# 1                                            No
# 2                                           Yes
# 3                                            No
# 4                                            No
#
#   From what type of device did you access My Account today? Dominant_Topic  \
# 0                                Desktop or laptop computer           10.0
# 1                                Desktop or laptop computer            8.0
# 2                                Desktop or laptop computer           12.0
# 3                                                Smartphone            6.0
# 4                                Desktop or laptop computer           15.0
#
#   Topic_Perc_Contrib  \
# 0             0.7738
# 1             0.7647
# 2             0.6865
# 3             0.5147
# 4             0.8118
#
#                                                                                      Keywords  \
# 0                          say, log, page, assessment, work, letter, agent, take, long, print
# 1         update, time, try, available, reassessment, error, balance, service, benefit, taxis
# 2     site, use, confusing, browser, terrible, navigate, user_friendly, chrome, fail, problem
# 3  document, login, ask, option, website, notice_assessment, request, question, upload, email
# 4                information, account, date, look, month, access, wait, tell, instalment, get
#
#                                                                                                   Text  \
# 0  [find, gst, assessment, log, time, setup, print, blank, page, say, page, print, print, page, bla...
# 1                                                     [dissatisfied, time, table, reassessment, taxis]
# 2                                  [site, user_friendly, specially, people, accustomed, use, computer]
# 3                                                            [option, login, canada, site, feel, hide]
# 4  [access, spouse, wife, account, representative, living, czech, republic, easy, reach, phone, exp...
#
#   Second_Topic Third_Topic
# 0          8.0         4.0
# 1          0.0         1.0
# 2          0.0         1.0
# 3         12.0         0.0
# 4          0.0         1.0
#
# [5 rows x 26 columns]

# %%
merged.shape
# Out:
# (4169, 26)

# %%
# merged.to_csv('df_with_topics_dissatisfaction_reason_jun14.csv')

# %%
merged.loc[merged['Dominant_Topic'] == 0 , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(10)
# Out:
#       Topic_Perc_Contrib  \
# 269               0.7647
# 155               0.6863
# 1016              0.6863
# 1608              0.6863
# 7                 0.6765
# 721               0.5799
# 729               0.5799
# 1004              0.5799
# 4131              0.5300
# 2455              0.5296
#
#                                                                                    dissatisfaction_reason
# 269   I want to see a list of received t4's. Thats it. specific data. NOT a summary, a list. Employer ...
# 155   The explanation as to why I owed more more was not clearly explained, I have no idea why it was ...
# 1016                                                               Areas say I don't owe others say I owe
# 1608                                                                        I have not received my refund
# 7     No explanation as to when I will receive my refund from a reassessment of med exp & no contact #...
# 721   2012  tax money hold by cra.i filed 2012 till today cra hold my money also no any action till to...
# 729   Advised a compliance hold on business account holding personal refund , Business says there is N...
# 1004  my refund is still on hold. I've resolved all the issues possible, including gst/hst payments an...
# 4131  If I have a place with email messages why can't I contact you through email at this place / mess...
# 2455                                Don't understand why I received the email about installmant payments?

# %%
for i in range(17):
    print(f'Some examples for topic {i}')
    print('')
    
    samples = merged.loc[merged['Dominant_Topic'] == i , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(20)
    print(samples['dissatisfaction_reason'].values)
    print(" ****************")
# Out:
# Some examples for topic 0
#
# ["I want to see a list of received t4's. Thats it. specific data. NOT a summary, a list. Employer A,B,C,D etc."
#  'The explanation as to why I owed more more was not clearly explained, I have no idea why it was reassessed'
#  "Areas say I don't owe others say I owe" 'I have not received my refund'
#  'No explanation as to when I will receive my refund from a reassessment of med exp & no contact # to enquire'
#  '2012  tax money hold by cra.i filed 2012 till today cra hold my money also no any action till today.'
#  'Advised a compliance hold on business account holding personal refund , Business says there is NO compliance issues and no HOLD'
#  "my refund is still on hold. I've resolved all the issues possible, including gst/hst payments and filing. There is no reason to hold my refund"
#  "If I have a place with email messages why can't I contact you through email at this place / message center"
#  "Don't understand why I received the email about installmant payments?"
#  'CRA reps  cannot  explain their own comments, CRA is power tripping again; cannot get a straight and honest answer from CRA'
#  'Nothing achieved not adding security code oy fixing the charit, donations to a more accurate list'
#  'no  answers  and  help line  was inaccessible'
#  'there’ s no explanation in the section that say I owe CRA money for overpayment of my CCB.'
#  'Could not add a cell phone number as a contact'
#  'You never get an aswer and the telephone people say one thing b but nothing is ever finalized'
#  'can never get a straight answer as to timelines'
#  'I have an active audit and even when I call no one had any answers  Very frustrating'
#  'Not clear where to enter CRA Security code that I received'
#  "I'm not satified with the received message"]
#  ****************
# Some examples for topic 1
#
# []
#  ****************
# Some examples for topic 2
#
# []
#  ****************
# Some examples for topic 3
#
# []
#  ****************
# Some examples for topic 4
#
# ['I am dissatisfied because I know I sent my 2017 tax return in to the CRA and its not showing up in any mail responses online or otherwise ie: (postage Canada mail) I need to know what to do next...'
#  "I mailed my 2015 tax return 2.5 months ago and I am unable to confirm receipt nor find out it's processing status"
#  'I did make a change return on my 2017 tax year  5 weeks ago.  I need to make another tax cahnge and as of today 2018-04-29 I cannot do it.'
#  'Change Tax Return was confusing. Could not find the Line I wanted to change.The add a line section did not help, search returned = 0'
#  'Unable to have my T5 Foreign tax box 16 Foreign tax credit applied to my 2017 tax return.'
#  'i couldnt find out if they completed reviewing my spouses income tax to adjust my child tax'
#  'I wanted to see the status of my submission regarding one of my tax returns instead i find out you reassessed the current year, again!'
#  'As non-resident I am unable to file my return electronically. Unable to see the progress status of my return.'
#  'I wanted to know how to make monthly payments to pay off my tax owing for this year.'
#  'I was not able to find out why my tax return is taking so long to be "processed"'
#  "Unable to find a summary of my tax returns. Unable to find instructions for removing a tax credit claimed in error in 'change my return' or determine how to file a paper amendment."
#  'Cannot find details about where my tax return is in the process. Would be nuce to see what stage and when I can expect it to be completed.'
#  "I couldn't resolve original issue.  I found the form I wanted (T1213) but it is (almost?) totally irrelevant to my situation as a retiree with one year of above=average income."
#  'I wanted to fill out form online but couldn’t find it so therefor couldn’t fill out what needed to be filled'
#  'I was unable to make changes to prior years tax returns beacuse i am still wating on one to be aproved that was submitted last novmber 2017'
#  'I wanted to change the amount of my tax deductions and was not able to find out where I could do this.'
#  'I NetFiled my 2016 return more than 4 weeks ago. It is still "in process". I would expect Netfile returns to complete faster than this.'
#  'The capacity of your system to submit files is too small.  I need to submiot 7 more files i.e 17 in total.  10 is too small.  Now what do I do???'
#  'No matter what I do, either calling or going online I am unable to find what is required from me in order to get my tax return.  My sons disability (T2201) expires in 2017 yet I am not being allowed'
#  'I submitted my tax return on march 24th and still remaining as being processed but not processed.']
#  ****************
# Some examples for topic 5
#
# []
#  ****************
# Some examples for topic 6
#
# ['Responded to audit request Sept 2017, no indication documents have been reviewed or assessed.'
#  'The limit to upload the documents was 150 MB but after 22 MB upload the webpage does not provide the option to add other documents.'
#  'The login question was not one of my questions'
#  "I selected, do not ask 2nd question when I login, well this is somewhat useless if it's always ignored"
#  "I don't recall answering any of the login questions that you asked and it didn't give option to go to another question. eventually it went to the next one after several wrong guesses"
#  'Required Repeated logins on multiple browsers due to repeated login failures with CER.010 error code'
#  'This website is specifically designed to dissuade people from requesting corrections or making disputes.'
#  'You make it SO DIFFICULT to login (hard to read screens, too many screens) & too difficult to navigate back & forth between screens (no "Back" option). Frustrating as heck.'
#  'I cannot ask question to CRA after business hours'
#  "I could't upload required documents for some reason"
#  'No option to save PDF copy of Notice of Assessment'
#  'I am unable to upload my notice of assesment from 2016 to the BC MSP website to confirm that I may qualify for subsidization.'
#  'I had multiple documents to upload:  It would have been preferable to upload them as a file instead of individually.'
#  'There should be a space to ask specific questions and possibly a phone number to make contact. CRA options do not cover all situations.'
#  'Could not upload document.  Not allowed for assessment requests! WHY?  Most Canadians do not own FAX machines.'
#  'It would be nice to request a confirmation that you have received all of my requested documents.'
#  'No ability to ask questions or to file requests.'
#  'Login process is very finicky. Website is not available for login most of the time. After login, website is really slow.'
#  "The directions given by the email from the cra didn't match the links that were on the websites"
#  'Login and registration is painful. The email notifications are terrible. The communication style is terrible.']
#  ****************
# Some examples for topic 7
#
# []
#  ****************
# Some examples for topic 8
#
# ['Error AC02: Our services are not available at this time. We are experiencing technical difficulties.'
#  'T slips were not available and the TFSA contribution room balance has not been updated for a transaction from last August'
#  'The notice of reassessment affected the cumulative tuition balance but did not provide me with the updated balances.'
#  'The Submit Documents service was not available for over 2 hours.'
#  'I tried to update my telephone number without any success - I tried for half an hour!!!'
#  'Submit documents of total size less than 150MB. Failed due to technical difficulties. Error: This service is currently unavailable. We apologize for any inconvenience this ma'
#  'more dissatisfied by the cra and the time table for my reassesment of my 2016 taxes'
#  'The submit document service was not available for the case number I was trying to upload documents for.'
#  'I have tried twice to submit documents & both times at the end of the process been met with an error msg "service currently not available Ref PPCS-SD-002"  Not impressed!'
#  'Login takes too long, services usually not available, never updated on time, poor service'
#  'You can never get on to the CRA website the first time you try. Most times you have to give up and try again another time. Insanely slow.'
#  'Revenue canada is not staffed sufficiently nor carries enough expertise to service anything more than a cursory load from the public. I try to connect daily. Never a successful response or resolution'
#  'Tried to update my cell number but would not accept the country code of 1 for Canada.'
#  'I was looking for slips for 2017, they are not available yet'
#  'CRA owes me money and I have tried calling the call centre many times and I cannot get through and get disconnected. I am so frustrated and sure hope someone reads this and does something about this!'
#  'I could not get my balance. There was an error code. I tried to call the 1-800 line but the que was full so I was disconnected'
#  'RC62 slips are not yet available'
#  "It's march 31 and some tslips were not available"
#  "I've tried to upload documents a several times over the past couple of days & always get an error."
#  'Keep geet error acc 003 when checking balance']
#  ****************
# Some examples for topic 9
#
# []
#  ****************
# Some examples for topic 10
#
# ['It took me 4 attampts to log in. The web site kept saying it was unavailable. I have registered for the financial institution log in but it would not work.'
#  "couldn't find my gst assessment  it logged me out/timed out during setup/printed a blank page/says only ONE page to be printed, printed 3 pages  2 were BLANK with just URL"
#  'The print button on the confirmation page does not work.'
#  'assessments and re-asssessments take too long. have been waiting almost 12 months for an assessment/re-assessment'
#  'The site took far too long to load pages. It took dozens of seconds per page load.'
#  'Je reçois une lettre qui me donne des renseignements qui ne semblent pas nécessaire parce que mon compte ouvre sans que les renseignements aient été captés!'
#  'Differences in amounts owing. One spot says one amount, while another says a different amount. Hard to determine which one is the correct amount owing.'
#  'It was annoying trying to log in and then it said I had 2 new messages when I did not.'
#  'It took me about a hour to get to a point where I could to talk to an agent.'
#  'assessments take too long to post.'
#  'I went to print my assessments and kept redirecting me server must of been down.'
#  'had to log out and log back in to change my password'
#  'logging on is stressful...where does one go  for example only certain BROWSERS work with CRA and they dont say say that'
#  'Kept getting kicked out and saying the system was not working'
#  'My 2017 assessment was delayed due to missing T4 data. Fixed in May but still no final assessment.'
#  'My service Canada login did not work.  Said it was previously revoked.  Went to CRA log in instead which luckily worked.'
#  'I attempted to print a copy of my available 2017 RRSP contribution.  The screen had my 2017 assessment but would not print all of the pages.  I could not get a print of my available contribution.'
#  'The letter said "your claim is allowed". That is unclear. It should have said "the audit is completed and no adjustment will be made" or "everything is in order". I did not "claim" anything to allow.'
#  'It took a long time to get registered, even with help from a CRA representitive who works with this stuff.'
#  'The assessment is taking far too long.....many many months']
#  ****************
# Some examples for topic 11
#
# []
#  ****************
# Some examples for topic 12
#
# ['Confusing site, I have university education and had thought I was literate but site is very difficult and unhelpful.'
#  'Site is a Bit confusing to use.'
#  'Very hard to use this site with android tablet.  Had to prepare text in advance to copy and paste in the appropriate sections.  Very time consuming.'
#  'The site is clearly not optimized for use on a tablet, resulting in me having to do a number of steps over. Very frustrating.'
#  'This site is not user friendly at all, specially for people, who are not accustomed to the use of computer.'
#  'Site is not laid out well.  The words chosen to describe various links are confusing in some areas.'
#  'There is noting like talking to a real person. the menues and workd used in this site are a little to formal. For People like me, that Inglish is a second lenguage.'
#  'Terrible site to navigate'
#  "because the site doesn't give clear understanding of why things are delayed"
#  'however hard to not use the back arrow key. When it is used, have to start all over again to sign in.'
#  'Content delivery, navigation is abysmal. This is the single worst organized site I have every used.'
#  'The site is brutal and inefficient at best.'
#  'Government  web-sites are disorganized and difficult to navigate'
#  "the site kept on breaking down and I couldn't finish my task"
#  'The service was unavailable when I wanted to use it (before 6am EST)'
#  'Hard to understand the site' "This site isn't easy to navigate"
#  'The site wrongly claims I have unread mail.'
#  'your site is not user friendly' 'This site is a joke.']
#  ****************
# Some examples for topic 13
#
# []
#  ****************
# Some examples for topic 14
#
# []
#  ****************
# Some examples for topic 15
#
# ['Continuous issue with CRA and finally got a representative on the phone while looking through my CRA account to assist me and the call got dropped from CRA end.'
#  "My bank sign-in and my wife's bank sign-in both access my account. her account is not accessable"
#  'could not access my spouse (my wife account) yet I am her representative, We are living in Czech republic not easy to reach by the phone (expensive)'
#  'CRA has debited amounts from my bank account and there is no record of in the CRA account & statement'
#  'the fact that i could access my cpp info from my account for individuals was not made clear anywhere i looked'
#  'dates? Some dates on statement of account are in the future'
#  'account information was a month out of date'
#  'Statement of account is out of date. CRA lost court decision more than a month ago and statement does not reflect that.'
#  'Have been waiting three months for adjustment that was agreed to by CRA on the phone and it is still not done'
#  'My wife and I  have joint Bank account cant register her into her cra account'
#  'My account information is not up to date'
#  'I am waiting for info on my dispute.  Should have been there 2 weeks ago.  Now promised for next week.'
#  'no information on what I was looking for. No date when it will be resolved.'
#  'Account is approx. 60 days out of date'
#  'Even though my account was up to date and current my account is always locked and Have to call anyways.'
#  'TFSA Contribution not up to date, Installment information difficult to understand'
#  'have been waiting for notification regarding appliction to be a representative on deceased persons account.  my message indictes 3 messages but i only access one and it is old.  dont understand.'
#  'I could not access my statement of account'
#  'My spouse’s RBC client card/password,defaults to my account vice her account. In other words my spouse can not assess her account using her own unique credentials.'
#  'The information I was looking for has not been added to my account yet.']
#  ****************
# Some examples for topic 16
#
# []
#  ****************
