# %%
from gensim import corpora
from parameters import *
from NLP_preprocessing import *
from LDA_model import *
from utils import read_data

import warnings
warnings.filterwarnings('ignore')


#read dataset, only keep desired text column and rename it
data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE)
cleaned_text = process_text_col(data, text_col = RENAMED_TEXT_COL)  # processed Text Data

# Create Dictionary
id2word = corpora.Dictionary(cleaned_text)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in cleaned_text]

# %%
coherence_vs_topics(texts= cleaned_text,corpus = corpus, dictionary = id2word ,min_number_topics = 4, max_number_topics = 20)

# from IPython.display import Image
# Image('out/coherence_Topics_plot.png')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [17:32<00:00, 61.89s/it]

# %%
NUM_TOPICS = 8
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
#8 topics
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
# df_dominant_topic.head()

df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# 4.0    1124
# 1.0     928
# 7.0     595
# 2.0     336
# 3.0     321
# 0.0     307
# 5.0     293
# 6.0     265
# Name: Dominant_Topic, dtype: int64

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 843              0.0               0.125
# 1303             0.0               0.125
# 1843             0.0               0.125
# 2089             0.0               0.125
# 2563             0.0               0.125
# 2567             0.0               0.125
# 2975             0.0               0.125
# 3098             0.0               0.125
# 3197             0.0               0.125
# 3377             0.0               0.125
# 3980             0.0               0.125
# 4045             0.0               0.125
#
#                                                                             Keywords  \
# 843   email, check, answer, ask, know, statement, understand, service, correct, user
# 1303  email, check, answer, ask, know, statement, understand, service, correct, user
# 1843  email, check, answer, ask, know, statement, understand, service, correct, user
# 2089  email, check, answer, ask, know, statement, understand, service, correct, user
# 2563  email, check, answer, ask, know, statement, understand, service, correct, user
# 2567  email, check, answer, ask, know, statement, understand, service, correct, user
# 2975  email, check, answer, ask, know, statement, understand, service, correct, user
# 3098  email, check, answer, ask, know, statement, understand, service, correct, user
# 3197  email, check, answer, ask, know, statement, understand, service, correct, user
# 3377  email, check, answer, ask, know, statement, understand, service, correct, user
# 3980  email, check, answer, ask, know, statement, understand, service, correct, user
# 4045  email, check, answer, ask, know, statement, understand, service, correct, user
#
#      Text
# 843    []
# 1303   []
# 1843   []
# 2089   []
# 2563   []
# 2567   []
# 2975   []
# 3098   []
# 3197   []
# 3377   []
# 3980   []
# 4045   []

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) < 0.18]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 159              5.0              0.1252
# 843              0.0              0.1250
# 919              0.0              0.1773
# 1004             6.0              0.1636
# 1081             3.0              0.1668
# 1090             3.0              0.1252
# 1263             2.0              0.1607
# 1303             0.0              0.1250
# 1434             2.0              0.1607
# 1481             3.0              0.1252
# 1482             3.0              0.1252
# 1634             4.0              0.1607
# 1843             0.0              0.1250
# 1991             6.0              0.1607
# 2084             1.0              0.1644
# 2089             0.0              0.1250
# 2314             7.0              0.1720
# 2552             3.0              0.1694
# 2563             0.0              0.1250
# 2567             0.0              0.1250
# 2975             0.0              0.1250
# 3015             6.0              0.1251
# 3041             6.0              0.1665
# 3098             0.0              0.1250
# 3197             0.0              0.1250
# 3377             0.0              0.1250
# 3980             0.0              0.1250
# 4045             0.0              0.1250
#
#                                                                                        Keywords  \
# 159   site, login, want, option, terrible, pension_plan, notice_assessment, today, have, direct
# 843              email, check, answer, ask, know, statement, understand, service, correct, user
# 919              email, check, answer, ask, know, statement, understand, service, correct, user
# 1004        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 1081            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1090            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1263                   receive, process, dec, hard, letter, contact, line, refund, child, place
# 1303             email, check, answer, ask, know, statement, understand, service, correct, user
# 1434                   receive, process, dec, hard, letter, contact, line, refund, child, place
# 1481            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1482            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1634                           find, account, tax, return, mail, say, log, year, unable, access
# 1843             email, check, answer, ask, know, statement, understand, service, correct, user
# 1991        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 2084                 information, change, payment, try, date, online, look, month, send, credit
# 2089             email, check, answer, ask, know, statement, understand, service, correct, user
# 2314                 information, pay, document, need, submit, tell, file, go, system, complete
# 2552            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 2563             email, check, answer, ask, know, statement, understand, service, correct, user
# 2567             email, check, answer, ask, know, statement, understand, service, correct, user
# 2975             email, check, answer, ask, know, statement, understand, service, correct, user
# 3015        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 3041        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 3098             email, check, answer, ask, know, statement, understand, service, correct, user
# 3197             email, check, answer, ask, know, statement, understand, service, correct, user
# 3377             email, check, answer, ask, know, statement, understand, service, correct, user
# 3980             email, check, answer, ask, know, statement, understand, service, correct, user
# 4045             email, check, answer, ask, know, statement, understand, service, correct, user
#
#                                                                                                      Text
# 159                                                                                               [ready]
# 843                                                                                                    []
# 919        [state, account, available, waste_time, waste, taxpayer, money, set, system, totally, useless]
# 1004      [refund, hold, resolve, issue, possible, include, gst_hst, payment, file, reason, hold, refund]
# 1081                           [file, return, march, june, details, completion, date, delay, frustrating]
# 1090                                                                                         [2017return]
# 1263                                             [month, file, taxis, receive, return, notice_assessment]
# 1303                                                                                                   []
# 1434                                             [notice_assessment, process, month, return, file, march]
# 1481                                                                                       [server_error]
# 1482                                                                                            [undated]
# 1634                                                              [file, taxis, march, wait, tax, refund]
# 1843                                                                                                   []
# 1991                                                     [benefit, suppose, update, today, tax, complete]
# 2084                                                           [server, able, let, download, return, day]
# 2089                                                                                                   []
# 2314  [site, work, open, google, chrome, widely, portal, waste, precious, time, try, figure, problem, ...
# 2552  [apply, extended, review, status, update, receive, submit, aug, tell, 1st, time, write, extend, ...
# 2563                                                                                                   []
# 2567                                                                                                   []
# 2975                                                                                                   []
# 3015                                                                                        [unorganized]
# 3041  [able, end, care, child, system, keep, tell, internal_server, error, technical_difficultie, unab...
# 3098                                                                                                   []
# 3197                                                                                                   []
# 3377                                                                                                   []
# 3980                                                                                                   []
# 4045                                                                                                   []

# %%
#Wordcloud 
get_wordcloud_LDA(ldamodel = lda_model, num_topics = NUM_TOPICS)

# %%
# word_count_topic(ldamodel = lda_model, num_topics = NUM_TOPICS , texts = cleaned_text)

# %%
sentences_chart(ldamodel=lda_model, corpus=corpus, start = 0, end = 14)

# %%
Plot_topic_dist(ldamodel= lda_model, num_topics = NUM_TOPICS, corpus = corpus)

# %%
tsne_plot(ldamodel = lda_model, corpus = corpus,num_topics = NUM_TOPICS , Keep_well_separated_pcnt = 0.35)

# %%
pyldavis_plot(ldamodel = lda_model ,corpus = corpus,  mds = "tsne")

# %%
def top3_topics_per_document(ldamodel, corpus):
    topics_top3 = []

    for i, corp in enumerate(corpus):
        topic_percs, wordid_topics, wordid_phivalues = ldamodel[corp]
        dominant_topic = sorted(topic_percs, key=lambda x: x[1], reverse=True)[0][0]
        try:
            topic2 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[1][0]
        except:
            topic2 = None        
        try:
            topic3 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[2][0]
        except:
            topic3 = None
        topics_top3.append((i, dominant_topic , topic2, topic3 ))       


    df = pd.DataFrame(topics_top3, columns = ['Document_Id', 'Dominant_Topic', 'Second_Topic', 'Third_Topic'])
    
    return df

# %%
top3_topics = top3_topics_per_document(ldamodel = lda_model, corpus = corpus)

# %%
len(top3_topics)

# %%
len(data)

# %%
cols = ['Quarter','Submitted date','What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.','Approximately how often do you visit My Account?',
 "Overall how satisfied were you with today's experience?", 'Which option did you choose to login to My Account?', 'Did/do you need to call the CRA to complete your visit/transaction today?',
 'Are you:', 'I live in...' ,
 'What is the highest level of education you have completed?', 'Would you be willing to indicate in which of the following age categories you belong?',
'What language do you speak most often at home?', 'Which of the following categories best describes your current employment status?', 'Which of the following categories best represents your most recent annual household income, before taxes?', 
'Are you an Aboriginal person?', 'Are you a person with a disability?', 'Are you a member of a visible minority group?', 'From what type of device did you access My Account today?']

def read_data_cols(in_dir, filename, text_col, renamed_text_col, text_language = 'EN' , other_cols = cols):
    assert len(renamed_text_col) > 0
    df = pd.read_csv(os.path.join(in_dir, filename))
    df.rename(columns={text_col: renamed_text_col}, inplace=True)
    columns = [renamed_text_col] + cols
    if text_language == 'EN':
        # filter english only and not null rows
        df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'EN'),
                    columns]
#     elif text_language == 'FR':
#         df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'FR'),
#                     [renamed_text_col]]
#     elif text_language == 'ALL':
#         df = df.loc[~df[renamed_text_col].isna(), [renamed_text_col]]

    else:
        raise ValueError

    df = df.reset_index()

    return df

# %%
org_data = read_data_cols(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE , other_cols = cols)

# %%
org_data.shape

# %%
merged = pd.concat([org_data, df_dominant_topic, top3_topics.loc[:, [ 'Second_Topic', 'Third_Topic']]], axis=1 , ignore_index = False)
merged.head()
# Out:
#    index  \
# 0     17
# 1     36
# 2     56
# 3     58
# 4     72
#
#                                                                                 dissatisfaction_reason  \
# 0  couldn't find my gst assessment  it logged me out/timed out during setup/printed a blank page/sa...
# 1                  more dissatisfied by the cra and the time table for my reassesment of my 2016 taxes
# 2  This site is not user friendly at all, specially for people, who are not accustomed to the use o...
# 3                                               The option to login on the canada.ca site feels hidden
# 4  could not access my spouse (my wife account) yet I am her representative, We are living in Czech...
#
#   Quarter Submitted date  \
# 0      Q4       1/4/2018
# 1      Q4       1/4/2018
# 2      Q4       1/5/2018
# 3      Q4       1/5/2018
# 4      Q4       1/5/2018
#
#   What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.  \
# 0                                                         Proof of income statement (option "C" print)
# 1                                                                                          Tax returns
# 2                                                                                          Tax returns
# 3                                                                                          Online mail
# 4                                                                                          Tax returns
#
#   Approximately how often do you visit My Account?  \
# 0                          This was my first visit
# 1                           Once per month or more
# 2                           Once per month or more
# 3                           Once or twice per year
# 4                         Once every 2 to 3 months
#
#   Overall how satisfied were you with today's experience?  \
# 0                                       Very dissatisfied
# 1                                       Very dissatisfied
# 2                                   Somewhat dissatisfied
# 3                                   Somewhat dissatisfied
# 4                                       Very dissatisfied
#
#   Which option did you choose to login to My Account?  \
# 0                            CRA user ID and password
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   Did/do you need to call the CRA to complete your visit/transaction today?  \
# 0                                                                       Yes
# 1                                                                       Yes
# 2                                                                        No
# 3                                                                        No
# 4                                                                        No
#
#   Are you:  ... Are you an Aboriginal person?  \
# 0     Male  ...                            No
# 1     Male  ...                            No
# 2     Male  ...                            No
# 3     Male  ...                            No
# 4     Male  ...                            No
#
#   Are you a person with a disability?  \
# 0                                 Yes
# 1                                  No
# 2                   Prefer not to say
# 3                                  No
# 4                                 Yes
#
#   Are you a member of a visible minority group?  \
# 0                                            No
# 1                                            No
# 2                                           Yes
# 3                                            No
# 4                                            No
#
#   From what type of device did you access My Account today? Dominant_Topic  \
# 0                                Desktop or laptop computer            4.0
# 1                                Desktop or laptop computer            3.0
# 2                                Desktop or laptop computer            5.0
# 3                                                Smartphone            5.0
# 4                                Desktop or laptop computer            4.0
#
#   Topic_Perc_Contrib  \
# 0             0.7686
# 1             0.6896
# 2             0.3688
# 3             0.5895
# 4             0.5577
#
#                                                                                     Keywords  \
# 0                           find, account, tax, return, mail, say, log, year, unable, access
# 1            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 2  site, login, want, option, terrible, pension_plan, notice_assessment, today, have, direct
# 3  site, login, want, option, terrible, pension_plan, notice_assessment, today, have, direct
# 4                           find, account, tax, return, mail, say, log, year, unable, access
#
#                                                                                                   Text  \
# 0  [find, gst, assessment, log, time, setup, print, blank, page, say, page, print, print, page, bla...
# 1                                                     [dissatisfied, time, table, reassessment, taxis]
# 2                                  [site, user_friendly, specially, people, accustomed, use, computer]
# 3                                                            [option, login, canada, site, feel, hide]
# 4  [access, spouse, wife, account, representative, living, czech, republic, easy, reach, phone, exp...
#
#   Second_Topic Third_Topic
# 0          0.0         3.0
# 1          1.0         2.0
# 2          6.0         2.0
# 3          1.0         2.0
# 4          5.0         7.0
#
# [5 rows x 26 columns]

# %%
merged.shape
# Out:
# (4169, 26)

# %%
# merged.to_csv('df_with_topics_dissatisfaction_reason.csv')

# %%
merged.loc[merged['Dominant_Topic'] == 0 , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(10)
# Out:
#       Topic_Perc_Contrib                          dissatisfaction_reason
# 628               0.0714                      It is not clearly laid out
# 720               0.0714              I was forced to change my password
# 3980              0.0714                                               .
# 3834              0.0714  Because I still have to call for clarification
# 3774              0.0714                               Prefer not to say
# 3377              0.0714                                         really?
# 3197              0.0714                                               .
# 3139              0.0714                       Because it’s not finished
# 3098              0.0714                                               x
# 3094              0.0714                               It’s not friendly

# %%
for i in range(8):
    print(f'Some examples for topic {i}')
    print('')
    
    samples = merged.loc[merged['Dominant_Topic'] == i , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(20)
    print(samples['dissatisfaction_reason'].values)
    print(" ****************")
# Out:
# Some examples for topic 0
#
# ['I will have to provide written statements regarding my misplaced cheque which seems unnecessary if the cheque has not been cashed.'
#  "You cheat honest hardwoking ppl out of money they deserve while those who don't even have the child get the benefit"
#  'TFSA contribution room is not reflecting 2017 transactions'
#  'I can never understand if I owe money or not'
#  'Impossible to get an answer'
#  'The installment payments made yesterday morning are not recorded on my account yet.'
#  'I want to know how Service Canada Calculate our OAS allowance, GIS but failed.'
#  'could not find unused net capital losses' 'No interactive service'
#  'I want to know my contribution room on my tsfa....I have waited well over a year and would like to know the amount real soon..thanks'
#  "Don't understand why I received the email about installmant payments?"
#  'Sometimes it is easier to understand a human instead.'
#  'All of my 2017 TFSA transactions are listed in the record BUT MY 2018 CONTRIBUTION ROOM IS INCORRECT because one of the withdrawals is omitted in the calculation of contribution room.'
#  'Was looking for TFSA contribution room. Information provided is not current. TFASA contrubution made in is March 2017 was not reflected in the contribution room.'
#  'to find my carry-over loss, it can NOT be found in myCRA (https://www.canada.ca/en/revenue-agency/services/e-services/e-services-individuals/mycra.html).  WHY?'
#  'I am trying to get my 2016 assessment re-examined based upon a mistake I made on my 2013 return. On my 2013 I claimed a capital loss but mistakenly also claimed it on T2017 as a capital gain carryove'
#  'Answer from CRA was irrelevant' 'TFSA 2017 contribution not reflected'
#  'The current year TFSA transactions are not posted, leading to errors.  In the TFSA contribution room, a negative balance (overcontribution) is shown in brackets.  Show it in BOLD RED as a negative.'
#  "The service is so limited that it isn't really much of a service.  If the CRA were to expand services -- especially submission of documents -- this would be a great improvement."]
#  ****************
# Some examples for topic 1
#
# ['I have been trying to change my marital status for months. It was under review. I have sent in extra documentation. Still nothing is changed. I can’t change it online now because it’s been reviewed.'
#  'The information was essentially 12 months out of date and couched with so many weasel words to be of no value.'
#  'I got a notice about a request for information but no information about how to get the information to CRA'
#  'Not enough information on why payments magically changed month to month.'
#  'Sent 2proof of rental payments for year2017 and still have not had a any feedback'
#  'Did not get the info I was looking for, re monies owed and a payment made'
#  'Sick of waiting for months and months for adjustments to be rectified'
#  'The questions marks for sum of the Dates and the 2014 Credits'
#  'Still no information on my Gst/Hst and Trillium benefits'
#  'I have been waiting 10 months for something which published 2018-2019 service standards say should take about 2 weeks. Even double that would have been acceptable. 10 months is not acceptable.'
#  'There was not enough information about my change in benefits.'
#  'No way to send my request to CRA'
#  'Didnt have the up to date info I was looking for.'
#  'Been waiting since august to get my credits'
#  'The information I was looking for was unavailable and I have to call CRA now.'
#  'Getting ACC-003 message. Have been doing so for a week.'
#  'We are less than 10 days from gst/hst benefits but the information on payments is not up to date as well as child tax benefits not being up to date with less than a month for next payment'
#  'My information is not upto date' 'was looking for rc62 info'
#  'conflicting info regarding balances']
#  ****************
# Some examples for topic 2
#
# ['my DTC was declined, no reason is given.'
#  'I could not navigate easily - the layout is not really intuitive and the terminology is too specialized and not really clear for a layman'
#  'No connection to DTC' 'still have not received response'
#  'I have not received my refund' 'too hard to navigate'
#  'No explanation as to when I will receive my refund from a reassessment of med exp & no contact # to enquire'
#  'I found no connection to medical deductions eligibility'
#  'I had registered my child as dependent and now it is not there and I did not receive my CTC'
#  "i received a retroactive pension payment and you people did a reassessment in November and are demanding arrears interest. THAT'S NOT FAIR! we both received that information in October. That's mean!"
#  "I am trying to fix the pension splitting and it doesn't explain well"
#  'only Fax is accepted ; not in email or attachment to submit document, lengthy procedure'
#  'Receive no information other than DTC was approved'
#  'Waiting to be approved for mat leave. And still nothing'
#  'No results yet. Still fighting for what is mine.'
#  'well you are doing things in my account with child tax with no explanation filing an objection is conveluded'
#  'no results' 'cannot get results' 'They receive'
#  "I didn't like the result"]
#  ****************
# Some examples for topic 3
#
# ['Sometimes I can see my detailed assessment  but most of the time I cannot see.  Sounds very strange and disappointment'
#  'Does not give updates on adjustments when taken longer time than usual'
#  'cant get a hold of anybody' 'Everything takes FOREVER with the CRA'
#  'There’s no updates or time'
#  'more dissatisfied by the cra and the time table for my reassesment of my 2016 taxes'
#  'I have a relatively simple reassessment that has now taken almost 5 months and it is still not done.'
#  'Many (excessive) clicks to conduct simple tasks, questionable organization.'
#  'Still no action on my grievance.'
#  'Time to process anything is taking more time then it should.'
#  'Its taking way too long for a reassessment.'
#  'taking forever for my reassessment'
#  "Still haven't been informed about my reassessment"
#  'The RC62 is not yet available'
#  'No mentioned estimated completion time for assessment'
#  'It took a ridiculously long time to upload documents when it could have been much easier and faster. CRA seems to delight in making things difficult for people. Really irked and annoyed.'
#  'i have been wating a verry long time for anykind of responce to getting my babby bonus and still nothing no updates no phone calls im just left to wonder'
#  'I was unable to find what a code meant, its so vauge it was of no help'
#  'It took a long time to get registered, even with help from a CRA representitive who works with this stuff.'
#  'prefer not to say']
#  ****************
# Some examples for topic 4
#
# ["I can't access all my mail. It says I have 5 unread mail items but I can't access them."
#  "Too hrd to find things and you can't see all of your account details in one spot"
#  'Losing $1207.09 I earned to some monkey so he can piss it out of a plane!'
#  'Could not find TI general for any years on my account'
#  'Unable to print 2016 Tax assessment'
#  "it's not easy to find the link between my accounts"
#  'Unable to find my Instalment Reminder.'
#  'When I tried to open a mail in my Inbox after logging in to My Account, it said that I’m not authorized to view.'
#  "login thru our BMO account WILL ONLY bring up my wife's CRA account -- Unable to access my account - after a logout from wife's"
#  'Unable to see my account contributions over the year.'
#  'Unable to access my 2017 assessment'
#  'had to log out and log back in to change my password'
#  "cause i can't seem to switch my sign in partner"
#  'I was unable to change my password to my account.'
#  'no details on tax return' 'I could not find my tax returns'
#  "couldn't find my gst assessment  it logged me out/timed out during setup/printed a blank page/says only ONE page to be printed, printed 3 pages  2 were BLANK with just URL"
#  'Was unable to find my 2016 tax return and print it so I could take it to my accountant so she could see where I made my mistakes'
#  'My account says there is 1 unread mail but when I open ever mail and close it still says 1 unread'
#  'It is very perplexing that I can not also access the accounts of the corporation(s) for which I have authority']
#  ****************
# Some examples for topic 5
#
# ['No option to save PDF copy of Notice of Assessment'
#  'Login was painful on mobile as far too small and poorly laid out.  MyCRA mobile site is a joke and beyond useless.'
#  "I want a printable version of my NOA for my accountant and it doesn't allow you to download a printable version!!"
#  'Having to do a survey upon exiting'
#  'could not download Notice of Assessment'
#  'your site is not user friendly'
#  'I wanted to see 2017 notice of assessment but I could not see.'
#  'This site is not User Friendly' 'No T4 Slips visible.'
#  'This site is a joke.'
#  'tecknowledge today allows the gov. & bus. to have T4A T4AP slips etc. ready for citizens as of January 8 why the delay'
#  'Your website is very poorly designed !!!   VERY, VERY POORLY DESIGNED !!!!!'
#  'It takes too long to upload documents as the screens keep refreshing every time.'
#  'Government  web-sites are disorganized and difficult to navigate'
#  'to many options and not enough transparency to what you are entitled'
#  'Depending on where I log in, I get either a mobile version or the full version. Mobile version does not have the mail feature. Very annoying.'
#  'Locked out of my account, very complicated to recover.'
#  'Notice of Assessment is in French - I don’t speak French!!!'
#  'i wanted to lodge a complained but was unable to do so.'
#  'I had wished to save a PDF version of my Notice of Assessment, however I could not find anyway to do that. I right clicked Save As, but that ended up as a folder with many parts, no PDF in folder.']
#  ****************
# Some examples for topic 6
#
# ['my problem hasnot been resolved since 05/18'
#  'The issues I have were not resolved.' 'Issue still not resolved.'
#  'Je reçois une lettre qui me donne des renseignements qui ne semblent pas nécessaire parce que mon compte ouvre sans que les renseignements aient été captés!'
#  'Required Repeated logins on multiple browsers due to repeated login failures with CER.010 error code'
#  "couldn't read my mail because of tech problem"
#  'TFSA contribution amount 2018 is not updated yet.'
#  'Reassessments taking too long' 'because you are shitty period'
#  '2017 T-slips still not posted'
#  'The site is brutal and inefficient at best.'
#  'Not sure why processing is taking so long. Its been 6 days with no further updates..just "in process"'
#  'The website basically crashed in the middle of my session, so I could not continue what I was doing.'
#  "I deleted my home address and want to update it again. Why can't I update my home address after I deleted it? The web page system seems to have some bug with it."
#  'The password requirement of no special characters always trips me up. Let me have special characters!'
#  'Agent' 'no good' 'not updated enough' 'Not updatef' 'It’s not updated']
#  ****************
# Some examples for topic 7
#
# ["Couldn't submit new income number yesterday or today"
#  'System tells postal code is invalid.'
#  'Because I needed my CCB. I don’t get any kinda of income for him.'
#  "The website has very confusing information. It's awful."
#  'Cannot locate information I need.'
#  'Information I need is not complete yet'
#  'Not all information is viewable on website'
#  'I need the information from my RC62'
#  'You should be able to load all documents up at once with one brief comment overall what is the purpose of the documents. My filenames were organized well and the information is communicated clearly!'
#  'No new info' "I didn't get the information i needed"
#  'Information I was told would be was not there'
#  'The information wasn’t there nd I will call CRA tomorrow.'
#  'I can’t get the information I need' 'website confusing'
#  'The information I sought was not there'
#  'would let me do what i needed to do'
#  'i would like to remove representatives'
#  'I cannot find the documents I submitted or proof they were submitted'
#  'Cannot locate information slip information needed']
#  ****************
