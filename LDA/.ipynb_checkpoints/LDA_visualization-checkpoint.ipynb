# %%
from gensim import corpora
from parameters import *
from NLP_preprocessing import *
from LDA_model import *

import warnings
warnings.filterwarnings('ignore')


#read dataset, only keep desired text column and rename it
data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE)
cleaned_text = process_text_col(data, text_col = RENAMED_TEXT_COL)  # processed Text Data

# Create Dictionary
id2word = corpora.Dictionary(cleaned_text)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in cleaned_text]

# %%
# coherence_vs_topics(texts= cleaned_text,corpus = corpus, dictionary = id2word ,min_number_topics = 5, max_number_topics = 15 )

from IPython.display import Image
Image('out/coherence_Topics_plot.png')

# %%
#NUM_TOPICS = 12 
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
df_dominant_topic.head()
# Out:
#    Dominant_Topic  Topic_Perc_Contrib  \
# 0             8.0              0.7277
# 1             1.0              0.4595
# 2             8.0              0.5109
# 3             3.0              0.3038
# 4             4.0              0.5512
#
#                                                                           Keywords  \
# 0           not, site, available, log, page, work, assessment, line, website, link
# 1                    car, time, want, email, get, check, error, call, owe, message
# 2           not, site, available, log, page, work, assessment, line, website, link
# 3  login, option, ask, terrible, response, child, hour, confuse, include, days_ago
# 4           not, information, account, pay, look, need, year, document, wait, 2017
#
#                                                                                                   Text
# 0  [not, find, assessment, log, time, setup, print, blank_page, say, page, print, print, page, blan...
# 1                                           [dissatisfied, car, time, table, reassessment_2016, taxis]
# 2                          [site, not, user_friendly, specially, people, not, accustom, use, computer]
# 3                                                            [option, login, canada, site, feel, hide]
# 4  [not, access, spouse, wife, account, representative, living, czech, republic, not, easy, reach, ...

# %%
#Wordcloud 
get_wordcloud_LDA(ldamodel = lda_model, num_topics = NUM_TOPICS)

# %%
word_count_topic(ldamodel = lda_model, num_topics = NUM_TOPICS , texts = cleaned_text)

# %%
sentences_chart(ldamodel=lda_model, corpus=corpus, start = 0, end = 10)

# %%
Plot_topic_dist(ldamodel= lda_model, num_topics = NUM_TOPICS, corpus = corpus)

# %%
tsne_plot(ldamodel = lda_model, corpus = corpus,num_topics = NUM_TOPICS , Keep_well_separated_pcnt = 0.2)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 4095 samples in 0.013s...
# [t-SNE] Computed neighbors for 4095 samples in 0.493s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4095
# [t-SNE] Computed conditional probabilities for sample 2000 / 4095
# [t-SNE] Computed conditional probabilities for sample 3000 / 4095
# [t-SNE] Computed conditional probabilities for sample 4000 / 4095
# [t-SNE] Computed conditional probabilities for sample 4095 / 4095
# [t-SNE] Mean sigma: 0.015881
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.389580
# [t-SNE] KL divergence after 1000 iterations: 1.398761
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1313">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="6c5f8888-bee2-4483-975a-90d1df815741" data-root-id="1314"></div>

# %%
pyldavis_plot(ldamodel = lda_model ,corpus = corpus,  mds = "tsne")
# Out:
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 4      111.092506 -133.722946       1        1  21.745768
# 6       34.946613  107.064590       2        1  16.428877
# 8      -28.088213 -159.949036       3        1  11.521559
# 1      147.698074   21.369604       4        1  10.799097
# 5      -97.501183  126.981384       5        1  10.595476
# 0       30.312096  -32.794945       6        1   9.866730
# 7     -155.443665 -118.494690       7        1   8.350454
# 3     -204.248108   22.596130       8        1   5.820305
# 2      -79.404678   -6.864717       9        1   4.871728, topic_info=             Term         Freq        Total Category  logprob  loglift
# 5             not  3348.000000  3348.000000  Default  30.0000  30.0000
# 12            car   572.000000   572.000000  Default  29.0000  29.0000
# 3            find   691.000000   691.000000  Default  28.0000  28.0000
# 90    information   802.000000   802.000000  Default  27.0000  27.0000
# 30        account   616.000000   616.000000  Default  26.0000  26.0000
# ...           ...          ...          ...      ...      ...      ...
# 1125   apparently    13.069230    14.019762   Topic9  -4.8471   2.9515
# 1526      concern    19.092365    20.511185   Topic9  -4.4681   2.9500
# 622       divorce    16.547749    18.016266   Topic9  -4.6112   2.9367
# 750      schedule    15.260701    16.907190   Topic9  -4.6921   2.9193
# 1723         2019    20.020702    42.541016   Topic9  -4.4206   2.2680
#
# [311 rows x 6 columns], token_table=      Topic      Freq   Term
# term
# 276       3  0.969712   2016
# 147       1  0.992058   2017
# 41        7  0.981093   2018
# 1723      6  0.493641   2019
# 1723      9  0.470135   2019
# ...     ...       ...    ...
# 88        9  0.980785   wish
# 96        3  0.989760   work
# 1309      7  0.970934  write
# 706       1  0.977972  wrong
# 183       1  0.997079   year
#
# [290 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 7, 9, 2, 6, 1, 8, 4, 3])
