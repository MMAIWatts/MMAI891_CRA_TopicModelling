# %%
from gensim import corpora
from parameters import *
from NLP_preprocessing import *
from LDA_model import *
from utils import read_data

import warnings
warnings.filterwarnings('ignore')


#read dataset, only keep desired text column and rename it
data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE)
cleaned_text = process_text_col(data, text_col = RENAMED_TEXT_COL)  # processed Text Data

# Create Dictionary
id2word = corpora.Dictionary(cleaned_text)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in cleaned_text]

# %%
coherence_vs_topics(texts= cleaned_text,corpus = corpus, dictionary = id2word ,min_number_topics = 4, max_number_topics = 20)

# from IPython.display import Image
# Image('out/coherence_Topics_plot.png')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [16:21<00:00, 57.71s/it]

# %%
NUM_TOPICS = 8
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
#8 topics
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
# df_dominant_topic.head()

df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# 4.0    1096
# 6.0     741
# 1.0     735
# 5.0     424
# 0.0     389
# 3.0     350
# 2.0     233
# 7.0     201
# Name: Dominant_Topic, dtype: int64

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 843              0.0               0.125
# 1303             0.0               0.125
# 1843             0.0               0.125
# 2089             0.0               0.125
# 2563             0.0               0.125
# 2567             0.0               0.125
# 2975             0.0               0.125
# 3098             0.0               0.125
# 3197             0.0               0.125
# 3377             0.0               0.125
# 3980             0.0               0.125
# 4045             0.0               0.125
#
#                                                                        Keywords  \
# 843   update, able, email, check, answer, ask, know, understand, message, thing
# 1303  update, able, email, check, answer, ask, know, understand, message, thing
# 1843  update, able, email, check, answer, ask, know, understand, message, thing
# 2089  update, able, email, check, answer, ask, know, understand, message, thing
# 2563  update, able, email, check, answer, ask, know, understand, message, thing
# 2567  update, able, email, check, answer, ask, know, understand, message, thing
# 2975  update, able, email, check, answer, ask, know, understand, message, thing
# 3098  update, able, email, check, answer, ask, know, understand, message, thing
# 3197  update, able, email, check, answer, ask, know, understand, message, thing
# 3377  update, able, email, check, answer, ask, know, understand, message, thing
# 3980  update, able, email, check, answer, ask, know, understand, message, thing
# 4045  update, able, email, check, answer, ask, know, understand, message, thing
#
#      Text
# 843    []
# 1303   []
# 1843   []
# 2089   []
# 2563   []
# 2567   []
# 2975   []
# 3098   []
# 3197   []
# 3377   []
# 3980   []
# 4045   []

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) < 0.18]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 159              7.0              0.1254
# 606              6.0              0.1607
# 843              0.0              0.1250
# 908              5.0              0.1607
# 916              3.0              0.1607
# 1004             0.0              0.1635
# 1090             7.0              0.1252
# 1198             3.0              0.1607
# 1303             0.0              0.1250
# 1481             7.0              0.1252
# 1482             7.0              0.1252
# 1523             6.0              0.1607
# 1841             2.0              0.1636
# 1843             0.0              0.1250
# 1991             0.0              0.1607
# 2052             7.0              0.1651
# 2089             0.0              0.1250
# 2360             4.0              0.1608
# 2432             2.0              0.1445
# 2563             0.0              0.1250
# 2567             0.0              0.1250
# 2612             7.0              0.1675
# 2813             3.0              0.1797
# 2972             4.0              0.1771
# 2975             0.0              0.1250
# 3015             7.0              0.1253
# 3098             0.0              0.1250
# 3197             0.0              0.1250
# 3377             0.0              0.1250
# 3980             0.0              0.1250
# 4045             0.0              0.1250
#
#                                                                                 Keywords  \
# 159                 want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 606                 information, payment, pay, look, wait, tell, get, balance, owe, show
# 843            update, able, email, check, answer, ask, know, understand, message, thing
# 908   account, access, instalment, error, help, statement, view, terrible, address, easy
# 916        time, available, reassessment, login, option, dec, service, take, long, taxis
# 1004           update, able, email, check, answer, ask, know, understand, message, thing
# 1090                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 1198       time, available, reassessment, login, option, dec, service, take, long, taxis
# 1303           update, able, email, check, answer, ask, know, understand, message, thing
# 1481                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 1482                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 1523                information, payment, pay, look, wait, tell, get, balance, owe, show
# 1841          site, letter, different, agent, line, user, place, difficult, make, direct
# 1843           update, able, email, check, answer, ask, know, understand, message, thing
# 1991           update, able, email, check, answer, ask, know, understand, message, thing
# 2052                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 2089           update, able, email, check, answer, ask, know, understand, message, thing
# 2360                     find, tax, receive, return, mail, say, need, log, year, process
# 2432          site, letter, different, agent, line, user, place, difficult, make, direct
# 2563           update, able, email, check, answer, ask, know, understand, message, thing
# 2567           update, able, email, check, answer, ask, know, understand, message, thing
# 2612                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 2813       time, available, reassessment, login, option, dec, service, take, long, taxis
# 2972                     find, tax, receive, return, mail, say, need, log, year, process
# 2975           update, able, email, check, answer, ask, know, understand, message, thing
# 3015                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 3098           update, able, email, check, answer, ask, know, understand, message, thing
# 3197           update, able, email, check, answer, ask, know, understand, message, thing
# 3377           update, able, email, check, answer, ask, know, understand, message, thing
# 3980           update, able, email, check, answer, ask, know, understand, message, thing
# 4045           update, able, email, check, answer, ask, know, understand, message, thing
#
#                                                                                                      Text
# 159                                                                                               [ready]
# 606                                                           [system, refund, issue, match, tell, phone]
# 843                                                                                                    []
# 908                                                       [online, mail, match, account, balance, record]
# 916                                                      [takes_long, time, set, find, information, site]
# 1004      [refund, hold, resolve, issue, possible, include, gst_hst, payment, file, reason, hold, refund]
# 1090                                                                                         [2017return]
# 1198                                            [unable, update, personal, information, error_code, time]
# 1303                                                                                                   []
# 1481                                                                                       [server_error]
# 1482                                                                                            [undated]
# 1523                                                      [easy, thing, online, information, live, agent]
# 1841                                    [report, suspicious, phone, click, link, information, understand]
# 1843                                                                                                   []
# 1991                                                     [benefit, suppose, update, today, tax, complete]
# 2052                                       [takes_long, time, navigate, site, find, information, seeking]
# 2089                                                                                                   []
# 2360                                                      [find, way, open, dispute, register, weeks_ago]
# 2432                                             [find, look, site, unto, date, late, tfsa, contribution]
# 2563                                                                                                   []
# 2567                                                                                                   []
# 2612                                                             [site, delay, assess, taxis, year, wait]
# 2813  [attempt, complete, submission, document, audits, time, time, service_unavailable, notice, compl...
# 2972  [easy_navigate, option, need, able, download_pdf, file, instalment, tax, document, personal, inf...
# 2975                                                                                                   []
# 3015                                                                                        [unorganized]
# 3098                                                                                                   []
# 3197                                                                                                   []
# 3377                                                                                                   []
# 3980                                                                                                   []
# 4045                                                                                                   []

# %%
#Wordcloud 
get_wordcloud_LDA(ldamodel = lda_model, num_topics = NUM_TOPICS)

# %%
# word_count_topic(ldamodel = lda_model, num_topics = NUM_TOPICS , texts = cleaned_text)

# %%
sentences_chart(ldamodel=lda_model, corpus=corpus, start = 0, end = 14)

# %%
# Plot_topic_dist(ldamodel= lda_model, num_topics = NUM_TOPICS, corpus = corpus)

# %%
# tsne_plot(ldamodel = lda_model, corpus = corpus,num_topics = NUM_TOPICS , Keep_well_separated_pcnt = 0.35)

# %%
# pyldavis_plot(ldamodel = lda_model ,corpus = corpus,  mds = "tsne")

# %%
def top3_topics_per_document(ldamodel, corpus):
    topics_top3 = []

    for i, corp in enumerate(corpus):
        topic_percs, wordid_topics, wordid_phivalues = ldamodel[corp]
        dominant_topic = sorted(topic_percs, key=lambda x: x[1], reverse=True)[0][0]
        try:
            topic2 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[1][0]
        except:
            topic2 = None        
        try:
            topic3 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[2][0]
        except:
            topic3 = None
        topics_top3.append((i, dominant_topic , topic2, topic3 ))       


    df = pd.DataFrame(topics_top3, columns = ['Document_Id', 'Dominant_Topic', 'Second_Topic', 'Third_Topic'])
    
    return df

# %%
top3_topics = top3_topics_per_document(ldamodel = lda_model, corpus = corpus)

# %%
len(top3_topics)
# Out:
# 4169

# %%
len(data)
# Out:
# 4169

# %%
cols = ['Quarter','Submitted date','What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.','Approximately how often do you visit My Account?',
 "Overall how satisfied were you with today's experience?", 'Which option did you choose to login to My Account?', 'Did/do you need to call the CRA to complete your visit/transaction today?',
 'Are you:', 'I live in...' ,
 'What is the highest level of education you have completed?', 'Would you be willing to indicate in which of the following age categories you belong?',
'What language do you speak most often at home?', 'Which of the following categories best describes your current employment status?', 'Which of the following categories best represents your most recent annual household income, before taxes?', 
'Are you an Aboriginal person?', 'Are you a person with a disability?', 'Are you a member of a visible minority group?', 'From what type of device did you access My Account today?']

def read_data_cols(in_dir, filename, text_col, renamed_text_col, text_language = 'EN' , other_cols = cols):
    assert len(renamed_text_col) > 0
    df = pd.read_csv(os.path.join(in_dir, filename))
    df.rename(columns={text_col: renamed_text_col}, inplace=True)
    columns = [renamed_text_col] + cols
    if text_language == 'EN':
        # filter english only and not null rows
        df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'EN'),
                    columns]
#     elif text_language == 'FR':
#         df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'FR'),
#                     [renamed_text_col]]
#     elif text_language == 'ALL':
#         df = df.loc[~df[renamed_text_col].isna(), [renamed_text_col]]

    else:
        raise ValueError

    df = df.reset_index()

    return df

# %%
org_data = read_data_cols(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE , other_cols = cols)

# %%
org_data.shape
# Out:
# (4169, 20)

# %%
merged = pd.concat([org_data, df_dominant_topic, top3_topics.loc[:, [ 'Second_Topic', 'Third_Topic']]], axis=1 , ignore_index = False)
merged.head()
# Out:
#    index  \
# 0     17
# 1     36
# 2     56
# 3     58
# 4     72
#
#                                                                                 dissatisfaction_reason  \
# 0  couldn't find my gst assessment  it logged me out/timed out during setup/printed a blank page/sa...
# 1                  more dissatisfied by the cra and the time table for my reassesment of my 2016 taxes
# 2  This site is not user friendly at all, specially for people, who are not accustomed to the use o...
# 3                                               The option to login on the canada.ca site feels hidden
# 4  could not access my spouse (my wife account) yet I am her representative, We are living in Czech...
#
#   Quarter Submitted date  \
# 0      Q4       1/4/2018
# 1      Q4       1/4/2018
# 2      Q4       1/5/2018
# 3      Q4       1/5/2018
# 4      Q4       1/5/2018
#
#   What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.  \
# 0                                                         Proof of income statement (option "C" print)
# 1                                                                                          Tax returns
# 2                                                                                          Tax returns
# 3                                                                                          Online mail
# 4                                                                                          Tax returns
#
#   Approximately how often do you visit My Account?  \
# 0                          This was my first visit
# 1                           Once per month or more
# 2                           Once per month or more
# 3                           Once or twice per year
# 4                         Once every 2 to 3 months
#
#   Overall how satisfied were you with today's experience?  \
# 0                                       Very dissatisfied
# 1                                       Very dissatisfied
# 2                                   Somewhat dissatisfied
# 3                                   Somewhat dissatisfied
# 4                                       Very dissatisfied
#
#   Which option did you choose to login to My Account?  \
# 0                            CRA user ID and password
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
#   Did/do you need to call the CRA to complete your visit/transaction today?  \
# 0                                                                       Yes
# 1                                                                       Yes
# 2                                                                        No
# 3                                                                        No
# 4                                                                        No
#
#   Are you:  ... Are you an Aboriginal person?  \
# 0     Male  ...                            No
# 1     Male  ...                            No
# 2     Male  ...                            No
# 3     Male  ...                            No
# 4     Male  ...                            No
#
#   Are you a person with a disability?  \
# 0                                 Yes
# 1                                  No
# 2                   Prefer not to say
# 3                                  No
# 4                                 Yes
#
#   Are you a member of a visible minority group?  \
# 0                                            No
# 1                                            No
# 2                                           Yes
# 3                                            No
# 4                                            No
#
#   From what type of device did you access My Account today? Dominant_Topic  \
# 0                                Desktop or laptop computer            4.0
# 1                                Desktop or laptop computer            3.0
# 2                                Desktop or laptop computer            7.0
# 3                                                Smartphone            3.0
# 4                                Desktop or laptop computer            5.0
#
#   Topic_Perc_Contrib  \
# 0             0.6566
# 1             0.6887
# 2             0.3695
# 3             0.3037
# 4             0.5801
#
#                                                                              Keywords  \
# 0                     find, tax, receive, return, mail, say, need, log, year, process
# 1       time, available, reassessment, login, option, dec, service, take, long, taxis
# 2                want, pension_plan, today, have, end, etc, detail, hour, slip, allow
# 3       time, available, reassessment, login, option, dec, service, take, long, taxis
# 4  account, access, instalment, error, help, statement, view, terrible, address, easy
#
#                                                                                                   Text  \
# 0  [find, gst, assessment, log, time, setup, print, blank, page, say, page, print, print, page, bla...
# 1                                                     [dissatisfied, time, table, reassessment, taxis]
# 2                                  [site, user_friendly, specially, people, accustomed, use, computer]
# 3                                                            [option, login, canada, site, feel, hide]
# 4  [access, spouse, wife, account, representative, living, czech, republic, easy, reach, phone, exp...
#
#   Second_Topic Third_Topic
# 0            3         1.0
# 1            2         6.0
# 2            2         3.0
# 3            5         2.0
# 4            7         0.0
#
# [5 rows x 26 columns]

# %%
merged.shape
# Out:
# (4169, 26)

# %%
merged.to_csv('df_with_topics_dissatisfaction_reason_jun14.csv')

# %%
merged.loc[merged['Dominant_Topic'] == 0 , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(10)
# Out:
#       Topic_Perc_Contrib  \
# 1490              0.8333
# 112               0.7812
# 171               0.7170
# 933               0.7083
# 194               0.7083
# 4044              0.7083
# 3207              0.7083
# 1780              0.7083
# 77                0.7040
# 183               0.6875
#
#                                                                                    dissatisfaction_reason
# 1490  You cheat honest hardwoking ppl out of money they deserve while those who don't even have the ch...
# 112                                            TFSA contribution room is not reflecting 2017 transactions
# 171                                        TFSA transactions and contribution room are extremely outdated
# 933                                                                      I can never get an update answer
# 194                                                                 TFSA contribution room wasn't updated
# 4044                                                                            Issue still not resolved.
# 3207                                                                 The issues I have were not resolved.
# 1780                                                         I can never understand if I owe money or not
# 77                                                            Poor support for issues. not clear guidance
# 183            Could not see any record of a dispute that was submitted, should get a confirmation email.

# %%
for i in range(8):
    print(f'Some examples for topic {i}')
    print('')
    
    samples = merged.loc[merged['Dominant_Topic'] == i , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(20)
    print(samples['dissatisfaction_reason'].values)
    print(" ****************")
# Out:
# Some examples for topic 0
#
# ["You cheat honest hardwoking ppl out of money they deserve while those who don't even have the child get the benefit"
#  'TFSA contribution room is not reflecting 2017 transactions'
#  'TFSA transactions and contribution room are extremely outdated'
#  'I can never get an update answer'
#  "TFSA contribution room wasn't updated" 'Issue still not resolved.'
#  'The issues I have were not resolved.'
#  'I can never understand if I owe money or not'
#  'Poor support for issues. not clear guidance'
#  'Could not see any record of a dispute that was submitted, should get a confirmation email.'
#  "I didn't remember the security question answer. Why not ask one of the other questions??"
#  "I want to check the how much I already contributed to TSFA and how much room do I still have in 2018, but I didn't get any information"
#  "my TFSA contribution room is wrong, is being corrected but this has been 7m and it's not finished yet, hopefully by Feb 9/18"
#  'I want to know my contribution room on my tsfa....I have waited well over a year and would like to know the amount real soon..thanks'
#  'I was not able to check if installment payments were received and assigned'
#  "Couldn't upload documents and CRA refuses to respond to queries.  A horrible experience."
#  'TFSA & RRSP data from 2017 still not updated and it is Feb 4, 2018'
#  'I WANT TO KNOW WHY MY CARRYBACK REASSESSMENT IS TAKING SO LONG. NOBODY CAN GIVE ME ANY ANSWERS.'
#  "Don't understand why I received the email about installmant payments?"
#  'what the hell is taking so long with my money?!?  why is this government holding my money from me?????  you know some of us are not as fortunate as others, you are starving me!']
#  ****************
# Some examples for topic 1
#
# ['I have been trying to change my marital status for months. It was under review. I have sent in extra documentation. Still nothing is changed. I can’t change it online now because it’s been reviewed.'
#  'Sick of waiting for months and months for adjustments to be rectified'
#  "Couldn't submit new income number yesterday or today"
#  'I try to send the document but it does not work.'
#  'i have questions and there is no way to contact via the website'
#  'Could not add a cell phone number as a contact'
#  'The system was unreliable and kept quitting.'
#  'could not upload file requested' 'No way to send my request to CRA'
#  'My CCB benefits are not up to date'
#  'Documents have not been reviewed yet and there is no feedback'
#  'System hung up and I will have to try again'
#  'Technical difficulties.  I have to keep trying to submit my document.'
#  "i can't submit my documents on Saturday evening, even though I uploaded them all."
#  "I wanted to change my daughter's DOB which I could not do.I've sent the documents of proof of my daughter's DOB by mail. But they haven't changed it yet."
#  'kept getting kicked out of system'
#  'Once again, the system was not working. If business had a track record like yours they would be out of business'
#  'Filed a complaint and when I submitted it I was sent to a blank page.'
#  "I wasn't sent a security code and it still didn't worm"
#  'We create an secure online profile, why can we not correct it? Been trying since July 2017 to get marital status corrected and date.']
#  ****************
# Some examples for topic 2
#
# ['Virtually impossible to recover ID that had been forgotten'
#  'Very difficult to register when you are blocked'
#  'Ei site is always unavailable on weekends to submit cards'
#  "I had to use 2 different devices to read a letter that wasn't all that important because logging in is such a pain. I have unregistered from online mail and gone back to snail mail because of it."
#  'I was forced to change my password' 'This site is a joke.'
#  'Your website is very poorly designed !!!   VERY, VERY POORLY DESIGNED !!!!!'
#  'Government  web-sites are disorganized and difficult to navigate'
#  "Impossible de voir le solde de mon compte; il  y a une semaine environ on m'a dit qu'on s'engageait à m'en informer d'ici au 18 septembre 2018 !!!!!"
#  'Very hard to use this site with android tablet.  Had to prepare text in advance to copy and paste in the appropriate sections.  Very time consuming.'
#  'This is one of the worst websites I have ever been forced to interact with - nebulous and misleading ("forced" is deliberate)'
#  'Still no action on my grievance.'
#  'The site is great but the formal dispute has not even been registered ion my account. No action taken on the part of CRA'
#  'Have to register annually because User ID and passwords are not remembered. Only use My Account once per year.'
#  'Because half of your customer service or agents give different answers of everything and they are very rude'
#  "Very difficult to navigate. There are many platforms and 'homes' for informtation"
#  'if online mail is not accessible during 3hr maintenance window, please inform me of that BEFORE I enter username, password and answer security question.'
#  'The web interface is rediculous and only works properly with Internet Explorer.  This is SUPER frustrating as we only have one device that uses IE and nowhere does it say that IE is a requirement!'
#  'Agent' 'I could not change my password.']
#  ****************
# Some examples for topic 3
#
# ['Does not give updates on adjustments when taken longer time than usual'
#  'There’s no updates or time' 'login took three attempts'
#  'Everything takes FOREVER with the CRA' 'cant get a hold of anybody'
#  'it take too long to login'
#  'i have been wating a verry long time for anykind of responce to getting my babby bonus and still nothing no updates no phone calls im just left to wonder'
#  'more dissatisfied by the cra and the time table for my reassesment of my 2016 taxes'
#  'I have a relatively simple reassessment that has now taken almost 5 months and it is still not done.'
#  'Getting to the Revenue Canada homepage took a long time.  Getting to the My Account webpage took a long time to connect as well.'
#  'No interactive service'
#  'to many options and not enough transparency to what you are entitled'
#  'Error AC02: Our services are not available at this time. We are experiencing technical difficulties.'
#  'Time to process anything is taking more time then it should.'
#  'Its taking way too long for a reassessment.'
#  'The first payment date range is listed backwards and then deemed not applicable due to conflicting conditions after a date within this range is selected.'
#  'The RC62 is not yet available' 'taking forever for my reassessment'
#  "Still haven't been informed about my reassessment"
#  'No mentioned estimated completion time for assessment']
#  ****************
# Some examples for topic 4
#
# ["I mailed my 2015 tax return 2.5 months ago and I am unable to confirm receipt nor find out it's processing status"
#  'Was unable to find my 2016 tax return and print it so I could take it to my accountant so she could see where I made my mistakes'
#  'I was unable to find out about my assessment as my return is still being prcessed'
#  'Losing $1207.09 I earned to some monkey so he can piss it out of a plane!'
#  "Because our 2016 tax return revisions haven't been processed yet after 2 years."
#  'could not find unused net capital losses'
#  'Autofill failed and I had to go back to the beginning of my return in TurboTax'
#  'My tax return has been with the CRA since June. No assessment yet!'
#  'Unable to print 2016 Tax assessment'
#  "I didn't find an answer to a question I had about my tax rebate"
#  "My tax return still hasn't been processed so I am not receiving child tax and may lose my home"
#  'You should have the facility to send e-mail to the CRA in response to e-mail received by the tax payer'
#  'Unable to print out results' 'unable to find what I need'
#  'could not find why i have not received my refund'
#  'cannot find what I need. You suck' 'I could not find my tax returns'
#  "The mail I received doesn't really make sense"
#  "I was looking for my last 3 years of tax returns which I need for family court and I couldn't find them. I could only find NOA not the tax returns."
#  "I'm in common law for more than 3 years now and somehow CRA changed my common law status for year 2015"]
#  ****************
# Some examples for topic 5
#
# ['I could not access my statement of account'
#  'I will have to provide written statements regarding my misplaced cheque which seems unnecessary if the cheque has not been cashed.'
#  'It is very perplexing that I can not also access the accounts of the corporation(s) for which I have authority'
#  'Needed sighted help. My screen reader was not enough to accomplish the tasks.'
#  "login thru our BMO account WILL ONLY bring up my wife's CRA account -- Unable to access my account - after a logout from wife's"
#  'Could not access 2018  periodic Installments'
#  'Statement of account was not working. Viewing the statement of accounts was the only reason I signed on today.'
#  'It should be easier to access my sisters account since she has signed forms for both online and oral discussion between myself and CRA'
#  'The statement of accounts is not in chronological order, which made it very confusing.'
#  'Not understanding the content'
#  'I could not view the balance and statement of account, despite repeated attempts due to a technical error, presumably, on the site AC-003'
#  'My statement of account is locked and I cannot access it.'
#  'The Statement of Account is confusing and not user friendly'
#  'Was trying to get a statement of my Installments and ther ewas an error and I could not get it.'
#  'could not open statement of account as service was out'
#  'Sign in too complicated. Pre-authorized debit too many steps'
#  'I opened to see a job posting. But, it was not available therein.'
#  "My bank sign-in and my wife's bank sign-in both access my account. her account is not accessable"
#  'Internal server error...could not access my notice of assesmehtb'
#  '2017 T-slips still not posted']
#  ****************
# Some examples for topic 6
#
# ['I made a payment 3 days ago and it still is not seen on CrA'
#  'Did not get the info I was looking for, re monies owed and a payment made'
#  'conflicting info regarding balances'
#  'Because I have been waiting for 32 days and still no specifications'
#  'was looking for rc62 info' 'Could not information I was looking for.'
#  "Information what I'm looking for was not there"
#  "it doesn't tell me what I was looking for and it should by now"
#  'information i am looking for is not here'
#  'The information I was looking for is not there.'
#  'Information I was told would be was not there'
#  'There was nothing for me to look at.. The information was not there.'
#  'I did not get the information I was looking for'
#  'No information on my last 2 payments'
#  'no information on what i was looking for'
#  'i would like to remove representatives'
#  'Looking for follow up information regarding document submission dating back to 2010. Nothing found.'
#  'I could not compete payment despite having the correct banking info'
#  'lack of information'
#  'Cant find the information i am looking for in regards to the UCCB']
#  ****************
# Some examples for topic 7
#
# ['tecknowledge today allows the gov. & bus. to have T4A T4AP slips etc. ready for citizens as of January 8 why the delay'
#  'It is not clearly laid out' 'No T4 Slips visible.'
#  'Status of active vs inactive agreements somewhat confusing'
#  'Depending on where I log in, I get either a mobile version or the full version. Mobile version does not have the mail feature. Very annoying.'
#  'I have an active audit and even when I call no one had any answers  Very frustrating'
#  'i wanted to lodge a complained but was unable to do so.' 'No Rc62 slip'
#  "I want a printable version of my NOA for my accountant and it doesn't allow you to download a printable version!!"
#  "your office continues to give me the run around. foo much BS with governments I hope you all have food to last you to the end of the month I DON'T"
#  "It was frustrating. Can't do what I logged in to do. Can't find solution on my own. Embedded links are like a rabbit trail with challenges backtracking."
#  'I am computer savvy, but I find this website totally dysfunctional and confusing and very frustrating to surf'
#  'I wish to submit a aothorization for me to handle tax issue of a friend.  But I am not allowed to do it.'
#  'Site is not laid out well.  The words chosen to describe various links are confusing in some areas.'
#  'Some of it is confusing.' "my 2018 slips aren't there" 'Too confusing'
#  "My T4 aren't loaded yet" "I couldn't do what I wanted"
#  'Everything takes so long']
#  ****************
