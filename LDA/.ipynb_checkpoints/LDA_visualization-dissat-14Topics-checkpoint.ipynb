# %%
from gensim import corpora
from parameters import *
from NLP_preprocessing import *
from LDA_model import *
from utils import read_data

import warnings
warnings.filterwarnings('ignore')


#read dataset, only keep desired text column and rename it
data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE)
cleaned_text = process_text_col(data, text_col = RENAMED_TEXT_COL)  # processed Text Data

# Create Dictionary
id2word = corpora.Dictionary(cleaned_text)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in cleaned_text]

# %%
coherence_vs_topics(texts= cleaned_text,corpus = corpus, dictionary = id2word ,min_number_topics = 4, max_number_topics = 20)

# from IPython.display import Image
# Image('out/coherence_Topics_plot.png')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [17:32<00:00, 61.89s/it]

# %%
NUM_TOPICS = 11
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
df_dominant_topic.head()
# Out:
#    Dominant_Topic  Topic_Perc_Contrib  \
# 0             8.0              0.8847
# 1             3.0              0.6188
# 2             4.0              0.3506
# 3             4.0              0.4417
# 4             2.0              0.5663
#
#                                                                                     Keywords  \
# 0                       find, say, need, log, page, assessment, work, benefit, user, address
# 1            time, online, submit, available, reassessment, email, want, error, way, balance
# 2  site, login, go, ask, option, notice_assessment, attempt, confirmation, enter, experience
# 3  site, login, go, ask, option, notice_assessment, attempt, confirmation, enter, experience
# 4             information, account, try, date, look, access, instalment, get, statement, new
#
#                                                                                                   Text
# 0  [find, gst, assessment, log, time, setup, print, blank, page, say, page, print, print, page, bla...
# 1                                                     [dissatisfied, time, table, reassessment, taxis]
# 2                                  [site, user_friendly, specially, people, accustomed, use, computer]
# 3                                                            [option, login, canada, site, feel, hide]
# 4  [access, spouse, wife, account, representative, living, czech, republic, easy, reach, phone, exp...

# %%
data.iloc[1303,].values
# Out:
# array([21015, '??'], dtype=object)

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 129              1.0              0.0909
# 159              1.0              0.0909
# 843              0.0              0.0909
# 1090             1.0              0.0909
# 1303             0.0              0.0909
# 1481             1.0              0.0909
# 1482             1.0              0.0909
# 1843             0.0              0.0909
# 2089             0.0              0.0909
# 2192             9.0              0.0909
# 2264             0.0              0.0909
# 2563             0.0              0.0909
# 2567             0.0              0.0909
# 2975             0.0              0.0909
# 3015             9.0              0.0909
# 3098             0.0              0.0909
# 3197             0.0              0.0909
# 3377             0.0              0.0909
# 3834             1.0              0.0909
# 3980             0.0              0.0909
# 4045             0.0              0.0909
# 4077             1.0              0.0909
#
#                                                                                           Keywords  \
# 129          mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 159          mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 843   answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 1090         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 1303  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 1481         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 1482         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 1843  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 2089  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 2192         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 2264  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 2563  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 2567  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 2975  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 3015         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 3098  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 3197  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 3377  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 3834         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 3980  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 4045  answer, terrible, dispute, unclear, impossible, password, ongoing, action, intuitive, accept
# 4077         mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
#
#                  Text
# 129            [hate]
# 159           [ready]
# 843                []
# 1090     [2017return]
# 1303               []
# 1481   [server_error]
# 1482        [undated]
# 1843               []
# 2089               []
# 2192     [applicable]
# 2264    [complicated]
# 2563               []
# 2567               []
# 2975               []
# 3015    [unorganized]
# 3098               []
# 3197               []
# 3377               []
# 3834  [clarification]
# 3980               []
# 4045               []
# 4077           [mind]

# %%
#11 topics
df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# 10.0    1100
# 2.0      855
# 3.0      576
# 8.0      566
# 7.0      335
# 5.0      315
# 4.0      241
# 0.0       94
# 6.0       78
# 1.0        7
# 9.0        2
# Name: Dominant_Topic, dtype: int64

# %%
df_dominant_topic[df_dominant_topic.Dominant_Topic == 9].head(30)
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 2192             9.0              0.0909
# 3015             9.0              0.0909
#
#                                                                                    Keywords  \
# 2192  mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
# 3015  mind, misspelling, tardy, prefer, arrange, clarification, repeat, meet, mac, winnipeg
#
#                Text
# 2192   [applicable]
# 3015  [unorganized]

# %%
NUM_TOPICS = 8
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
#8 topics
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
# df_dominant_topic.head()

df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# 4.0    1124
# 1.0     928
# 7.0     595
# 2.0     336
# 3.0     321
# 0.0     307
# 5.0     293
# 6.0     265
# Name: Dominant_Topic, dtype: int64

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 843              0.0               0.125
# 1303             0.0               0.125
# 1843             0.0               0.125
# 2089             0.0               0.125
# 2563             0.0               0.125
# 2567             0.0               0.125
# 2975             0.0               0.125
# 3098             0.0               0.125
# 3197             0.0               0.125
# 3377             0.0               0.125
# 3980             0.0               0.125
# 4045             0.0               0.125
#
#                                                                             Keywords  \
# 843   email, check, answer, ask, know, statement, understand, service, correct, user
# 1303  email, check, answer, ask, know, statement, understand, service, correct, user
# 1843  email, check, answer, ask, know, statement, understand, service, correct, user
# 2089  email, check, answer, ask, know, statement, understand, service, correct, user
# 2563  email, check, answer, ask, know, statement, understand, service, correct, user
# 2567  email, check, answer, ask, know, statement, understand, service, correct, user
# 2975  email, check, answer, ask, know, statement, understand, service, correct, user
# 3098  email, check, answer, ask, know, statement, understand, service, correct, user
# 3197  email, check, answer, ask, know, statement, understand, service, correct, user
# 3377  email, check, answer, ask, know, statement, understand, service, correct, user
# 3980  email, check, answer, ask, know, statement, understand, service, correct, user
# 4045  email, check, answer, ask, know, statement, understand, service, correct, user
#
#      Text
# 843    []
# 1303   []
# 1843   []
# 2089   []
# 2563   []
# 2567   []
# 2975   []
# 3098   []
# 3197   []
# 3377   []
# 3980   []
# 4045   []

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) < 0.18]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 159              5.0              0.1252
# 843              0.0              0.1250
# 919              0.0              0.1773
# 1004             6.0              0.1636
# 1081             3.0              0.1668
# 1090             3.0              0.1252
# 1263             2.0              0.1607
# 1303             0.0              0.1250
# 1434             2.0              0.1607
# 1481             3.0              0.1252
# 1482             3.0              0.1252
# 1634             4.0              0.1607
# 1843             0.0              0.1250
# 1991             6.0              0.1607
# 2084             1.0              0.1644
# 2089             0.0              0.1250
# 2314             7.0              0.1720
# 2552             3.0              0.1694
# 2563             0.0              0.1250
# 2567             0.0              0.1250
# 2975             0.0              0.1250
# 3015             6.0              0.1251
# 3041             6.0              0.1665
# 3098             0.0              0.1250
# 3197             0.0              0.1250
# 3377             0.0              0.1250
# 3980             0.0              0.1250
# 4045             0.0              0.1250
#
#                                                                                        Keywords  \
# 159   site, login, want, option, terrible, pension_plan, notice_assessment, today, have, direct
# 843              email, check, answer, ask, know, statement, understand, service, correct, user
# 919              email, check, answer, ask, know, statement, understand, service, correct, user
# 1004        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 1081            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1090            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1263                   receive, process, dec, hard, letter, contact, line, refund, child, place
# 1303             email, check, answer, ask, know, statement, understand, service, correct, user
# 1434                   receive, process, dec, hard, letter, contact, line, refund, child, place
# 1481            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1482            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 1634                           find, account, tax, return, mail, say, log, year, unable, access
# 1843             email, check, answer, ask, know, statement, understand, service, correct, user
# 1991        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 2084                 information, change, payment, try, date, online, look, month, send, credit
# 2089             email, check, answer, ask, know, statement, understand, service, correct, user
# 2314                 information, pay, document, need, submit, tell, file, go, system, complete
# 2552            time, available, reassessment, help, take, long, taxis, pass, code, frustrating
# 2563             email, check, answer, ask, know, statement, understand, service, correct, user
# 2567             email, check, answer, ask, know, statement, understand, service, correct, user
# 2975             email, check, answer, ask, know, statement, understand, service, correct, user
# 3015        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 3041        update, able, agent, difficult, post, disability, wrong, problem, browser, password
# 3098             email, check, answer, ask, know, statement, understand, service, correct, user
# 3197             email, check, answer, ask, know, statement, understand, service, correct, user
# 3377             email, check, answer, ask, know, statement, understand, service, correct, user
# 3980             email, check, answer, ask, know, statement, understand, service, correct, user
# 4045             email, check, answer, ask, know, statement, understand, service, correct, user
#
#                                                                                                      Text
# 159                                                                                               [ready]
# 843                                                                                                    []
# 919        [state, account, available, waste_time, waste, taxpayer, money, set, system, totally, useless]
# 1004      [refund, hold, resolve, issue, possible, include, gst_hst, payment, file, reason, hold, refund]
# 1081                           [file, return, march, june, details, completion, date, delay, frustrating]
# 1090                                                                                         [2017return]
# 1263                                             [month, file, taxis, receive, return, notice_assessment]
# 1303                                                                                                   []
# 1434                                             [notice_assessment, process, month, return, file, march]
# 1481                                                                                       [server_error]
# 1482                                                                                            [undated]
# 1634                                                              [file, taxis, march, wait, tax, refund]
# 1843                                                                                                   []
# 1991                                                     [benefit, suppose, update, today, tax, complete]
# 2084                                                           [server, able, let, download, return, day]
# 2089                                                                                                   []
# 2314  [site, work, open, google, chrome, widely, portal, waste, precious, time, try, figure, problem, ...
# 2552  [apply, extended, review, status, update, receive, submit, aug, tell, 1st, time, write, extend, ...
# 2563                                                                                                   []
# 2567                                                                                                   []
# 2975                                                                                                   []
# 3015                                                                                        [unorganized]
# 3041  [able, end, care, child, system, keep, tell, internal_server, error, technical_difficultie, unab...
# 3098                                                                                                   []
# 3197                                                                                                   []
# 3377                                                                                                   []
# 3980                                                                                                   []
# 4045                                                                                                   []

# %%
NUM_TOPICS = 14
lda_model = lda(num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=cleaned_text)
df_dominant_topic.head()
# Out:
#    Dominant_Topic  Topic_Perc_Contrib  \
# 0            12.0              0.7748
# 1             3.0              0.6143
# 2            12.0              0.4147
# 3            11.0              0.4144
# 4             2.0              0.6340
#
#                                                                            Keywords  \
# 0             say, site, log, page, want, error, assessment, work, help, understand
# 1     time, online, month, submit, available, reassessment, email, go, way, balance
# 2             say, site, log, page, want, error, assessment, work, help, understand
# 3                find, tax, change, return, mail, try, document, need, year, unable
# 4  information, account, date, look, access, wait, tell, instalment, get, statement
#
#                                                                                                   Text
# 0  [find, gst, assessment, log, time, setup, print, blank, page, say, page, print, print, page, bla...
# 1                                                     [dissatisfied, time, table, reassessment, taxis]
# 2                                  [site, user_friendly, specially, people, accustomed, use, computer]
# 3                                                            [option, login, canada, site, feel, hide]
# 4  [access, spouse, wife, account, representative, living, czech, republic, easy, reach, phone, exp...

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)]
# Out:
#       Dominant_Topic  Topic_Perc_Contrib  \
# 129              6.0              0.0714
# 159              4.0              0.0714
# 628              0.0              0.0714
# 720              0.0              0.0714
# 731              0.0              0.0714
# 754              6.0              0.0714
# 843              0.0              0.0714
# 894              0.0              0.0714
# 965              1.0              0.0714
# 974              0.0              0.0714
# 1076            12.0              0.0714
# 1090             0.0              0.0714
# 1303             0.0              0.0714
# 1441             0.0              0.0714
# 1481             0.0              0.0714
# 1482             7.0              0.0714
# 1560             9.0              0.0714
# 1580             0.0              0.0714
# 1665             1.0              0.0714
# 1843             0.0              0.0714
# 1963             0.0              0.0714
# 2089             0.0              0.0714
# 2192             0.0              0.0714
# 2264             0.0              0.0714
# 2379             0.0              0.0714
# 2461            13.0              0.0714
# 2521             0.0              0.0714
# 2563             0.0              0.0714
# 2567             0.0              0.0714
# 2621            11.0              0.0714
# 2805             0.0              0.0714
# 2975             0.0              0.0714
# 3015            10.0              0.0714
# 3054             0.0              0.0714
# 3094             0.0              0.0714
# 3098             0.0              0.0714
# 3139             0.0              0.0714
# 3197             0.0              0.0714
# 3377             0.0              0.0714
# 3521             9.0              0.0714
# 3774             0.0              0.0714
# 3834             0.0              0.0714
# 3980             0.0              0.0714
# 4045             0.0              0.0714
# 4077             1.0              0.0714
#
#                                                                                                  Keywords  \
# 129   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 159   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 628   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 720   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 731   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 754   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 843   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 894   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 965   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 974   mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1076                                say, site, log, page, want, error, assessment, work, help, understand
# 1090  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1303  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1441  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1481  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1482  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1560  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1580  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1665  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1843  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 1963  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2089  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2192  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2264  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2379  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2461           agent, thing, navigate, cumbersome, search, terrible, confusing, totally, little, computer
# 2521  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2563  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2567  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2621                                   find, tax, change, return, mail, try, document, need, year, unable
# 2805  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 2975  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3015  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3054  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3094  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3098  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3139  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3197  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3377  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3521  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3774  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3834  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 3980  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 4045  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
# 4077  mind, answer_question, user_friendly, repeat, browser, change_password, terrible, multiple, miss...
#
#                                      Text
# 129                                [hate]
# 159                               [ready]
# 628                        [clearly, lay]
# 720              [force, change_password]
# 731            [updates, answer_question]
# 754                             [updates]
# 843                                    []
# 894              [understanding, content]
# 965                     [change_password]
# 974                      [shitty, period]
# 1076                               [good]
# 1090                         [2017return]
# 1303                                   []
# 1441                      [easy_navigate]
# 1481                       [server_error]
# 1482                            [undated]
# 1560                             [prefer]
# 1580                    [answer_question]
# 1665                            [comment]
# 1843                                   []
# 1963                             [prefer]
# 2089                                   []
# 2192                         [applicable]
# 2264                        [complicated]
# 2379                             [finish]
# 2461                              [point]
# 2521                    [answer_question]
# 2563                                   []
# 2567                                   []
# 2621  [inform, base, pharmacy, calculate]
# 2805        [cause, switch, sign_partner]
# 2975                                   []
# 3015                        [unorganized]
# 3054                   [government, suck]
# 3094                           [friendly]
# 3098                                   []
# 3139                             [finish]
# 3197                                   []
# 3377                                   []
# 3521                [proof_income, prior]
# 3774                             [prefer]
# 3834                      [clarification]
# 3980                                   []
# 4045                                   []
# 4077                               [mind]

# %%
#14 topics
df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# 11.0    1309
# 2.0      854
# 3.0      752
# 12.0     455
# 8.0      393
# 5.0      324
# 13.0      40
# 0.0       32
# 1.0        3
# 9.0        2
# 6.0        2
# 10.0       1
# 7.0        1
# 4.0        1
# Name: Dominant_Topic, dtype: int64

# %%
# data.iloc[4077,]

# %%
#Wordcloud 
get_wordcloud_LDA(ldamodel = lda_model, num_topics = NUM_TOPICS)

# %%
# word_count_topic(ldamodel = lda_model, num_topics = NUM_TOPICS , texts = cleaned_text)

# %%
sentences_chart(ldamodel=lda_model, corpus=corpus, start = 0, end = 14)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-77c04b4d5e67> in <module>
# ----> 1 sentences_chart(ldamodel=lda_model, corpus=corpus, start = 0, end = 14)
#
# ~\Documents\GitHub\MMAI891_project\LDA\LDA_model.py in sentences_chart(ldamodel, corpus, start, end)
#     110             corp_cur = corp[i - 1]
#     111             topic_percs, wordid_topics, wordid_phivalues = ldamodel[corp_cur]
# --> 112             word_dominanttopic = [(ldamodel.id2word[wd], topic[0]) for wd, topic in wordid_topics]
#     113             ax.text(0.01, 0.5, "Doc " + str(i - 1) + ": ", verticalalignment='center',
#     114                     fontsize=16, color='black', transform=ax.transAxes, fontweight=700)
#
# ~\Documents\GitHub\MMAI891_project\LDA\LDA_model.py in <listcomp>(.0)
#     110             corp_cur = corp[i - 1]
#     111             topic_percs, wordid_topics, wordid_phivalues = ldamodel[corp_cur]
# --> 112             word_dominanttopic = [(ldamodel.id2word[wd], topic[0]) for wd, topic in wordid_topics]
#     113             ax.text(0.01, 0.5, "Doc " + str(i - 1) + ": ", verticalalignment='center',
#     114                     fontsize=16, color='black', transform=ax.transAxes, fontweight=700)
#
# IndexError: list index out of range

# %%
Plot_topic_dist(ldamodel= lda_model, num_topics = NUM_TOPICS, corpus = corpus)

# %%
tsne_plot(ldamodel = lda_model, corpus = corpus,num_topics = NUM_TOPICS , Keep_well_separated_pcnt = 0.35)

# %%
pyldavis_plot(ldamodel = lda_model ,corpus = corpus,  mds = "tsne")

# %%
def top3_topics_per_document(ldamodel, corpus):
    topics_top3 = []

    for i, corp in enumerate(corpus):
        topic_percs, wordid_topics, wordid_phivalues = ldamodel[corp]
        dominant_topic = sorted(topic_percs, key=lambda x: x[1], reverse=True)[0][0]
        try:
            topic2 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[1][0]
        except:
            topic2 = None        
        try:
            topic3 = sorted(topic_percs, key=lambda x: x[1], reverse=True)[2][0]
        except:
            topic3 = None
        topics_top3.append((i, dominant_topic , topic2, topic3 ))       


    df = pd.DataFrame(topics_top3, columns = ['Document_Id', 'Dominant_Topic', 'Second_Topic', 'Third_Topic'])
    
    return df

# %%
top3_topics = top3_topics_per_document(ldamodel = lda_model, corpus = corpus)

# %%
len(top3_topics)

# %%
len(data)

# %%
cols = ['Quarter','Submitted date','What was the main purpose of your visit today? Please choose one option only. The list represents broad categories, and you may be asked to further specify the main reason why you visited today.','Approximately how often do you visit My Account?',
 "Overall how satisfied were you with today's experience?", 'Which option did you choose to login to My Account?', 'Did/do you need to call the CRA to complete your visit/transaction today?',
 'Are you:', 'I live in...' ,
 'What is the highest level of education you have completed?', 'Would you be willing to indicate in which of the following age categories you belong?',
'What language do you speak most often at home?', 'Which of the following categories best describes your current employment status?', 'Which of the following categories best represents your most recent annual household income, before taxes?', 
'Are you an Aboriginal person?', 'Are you a person with a disability?', 'Are you a member of a visible minority group?', 'From what type of device did you access My Account today?']

def read_data_cols(in_dir, filename, text_col, renamed_text_col, text_language = 'EN' , other_cols = cols):
    assert len(renamed_text_col) > 0
    df = pd.read_csv(os.path.join(in_dir, filename))
    df.rename(columns={text_col: renamed_text_col}, inplace=True)
    columns = [renamed_text_col] + cols
    if text_language == 'EN':
        # filter english only and not null rows
        df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'EN'),
                    columns]
#     elif text_language == 'FR':
#         df = df.loc[(~df[renamed_text_col].isna()) & (df['Language answered'] == 'FR'),
#                     [renamed_text_col]]
#     elif text_language == 'ALL':
#         df = df.loc[~df[renamed_text_col].isna(), [renamed_text_col]]

    else:
        raise ValueError

    df = df.reset_index()

    return df

# %%
org_data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE , other_cols = cols)

# %%
org_data.shape

# %%
merged = pd.concat([org_data, top3_topics.loc[:, ['Dominant_Topic', 'Second_Topic', 'Third_Topic']]], axis=1 , ignore_index = False)
merged.head()

# %%
merged.shape

# %%
merged.to_csv('df_with_topics_dissatisfaction_reason.csv')

# %%
merged_11 = pd.concat([org_data, df_dominant_topic, top3_topics.loc[:, ['Second_Topic', 'Third_Topic']]], axis=1 , ignore_index = False)
merged_11.head()

# %%
merged_11.to_csv('df_with_topics_dissatisfaction_reason_11.csv')

# %%
merged['Dominant_Topic'].value_counts()

# %%
merged.loc[merged['Dominant_Topic'] == 3 , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(10)

# %%
for i in range(8):
    print(f'Some examples for topic {i}')
    print('')
    
    samples = merged.loc[merged['Dominant_Topic'] == i , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(10)
    print(samples['dissatisfaction_reason'].values)
    print(" ****************")
