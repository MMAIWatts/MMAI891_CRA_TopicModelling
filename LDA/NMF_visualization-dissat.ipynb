# %%
from gensim import corpora
from parameters import *
from NLP_preprocessing import *
from LDA_model import *
from utils import *
import warnings
warnings.filterwarnings('ignore')


#read dataset, only keep desired text column and rename it
data = read_data(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE)
cleaned_text = process_text_col(data, text_col = RENAMED_TEXT_COL)  # processed Text Data

# Create Dictionary
id2word = corpora.Dictionary(cleaned_text)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in cleaned_text]

# %%
coherence_vs_topics(method = 'NMF', texts= cleaned_text,corpus = corpus, dictionary = id2word ,min_number_topics = 4, max_number_topics = 20)

# from IPython.display import Image
# Image('../out/coherence_Topics_plot_NMF.png')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 17/17 [23:37<00:00, 83.36s/it]

# %%
NUM_TOPICS = 12
nmf_model = topic_modeling(method = 'NMF', num_topics = NUM_TOPICS, corpus = corpus , dictionary = id2word)

# %%
def format_topics_sentences(model, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(model[corpus]):
        row = row_list[0] if model.per_word_topics else row_list
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = model.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(
                    pd.Series([int(topic_num), round(prop_topic, 4), topic_keywords]), ignore_index=True)
            else:
                break

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    sent_topics_df.columns = ['Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
    return (sent_topics_df)

# %%
nmf_model.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f6a78db1ff1d> in <module>
# ----> 1 nmf_model.get_document_topics(cleaned_text)
#
# ~\anaconda3\lib\site-packages\gensim\models\nmf.py in get_document_topics(self, bow, minimum_probability, normalize)
#     494             return self._apply(corpus, **kwargs)
#     495
# --> 496         v = matutils.corpus2csc([bow], self.num_tokens)
#     497         h = self._solveproj(v, self._W, v_max=np.inf)
#     498
#
# ~\anaconda3\lib\site-packages\gensim\matutils.py in corpus2csc(corpus, num_terms, dtype, num_docs, num_nnz, printprogress)
#     156
#     157             # zip(*doc) transforms doc to (token_indices, token_counts]
# --> 158             doc_indices, doc_data = zip(*doc) if doc else ([], [])
#     159             indices.extend(doc_indices)
#     160             data.extend(doc_data)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
#12 topics

pd.set_option('display.max_colwidth', 100)
df_dominant_topic = format_topics_sentences(model=nmf_model, corpus=corpus, texts=cleaned_text)
df_dominant_topic.head()


df_dominant_topic.Dominant_Topic.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6ae6fb4d8a2b> in <module>
#       2
#       3 pd.set_option('display.max_colwidth', 100)
# ----> 4 df_dominant_topic = format_topics_sentences(model=nmf_model, corpus=corpus, texts=cleaned_text)
#       5 df_dominant_topic.head()
#       6
#
# ~\Documents\GitHub\MMAI891_project\LDA\LDA_model.py in format_topics_sentences(model, corpus, texts)
#     108     for i, row_list in enumerate(model[corpus]):
#     109         row = row_list[0] if model.per_word_topics else row_list
# --> 110         # print(row)
#     111         row = sorted(row, key=lambda x: (x[1]), reverse=True)
#     112         # Get the Dominant topic, Perc Contribution and Keywords for each document
#
# AttributeError: 'Nmf' object has no attribute 'per_word_topics'

# %%
df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) == round(1/NUM_TOPICS, 4)] #Classify them as other --42 answears

# %%
len(df_dominant_topic[round(df_dominant_topic.Topic_Perc_Contrib,4) < 0.1])

# %%
df_dominant_topic['Topic_final'] = np.where(df_dominant_topic.Topic_Perc_Contrib < 0.1, 99, df_dominant_topic.Dominant_Topic)
df_dominant_topic.head()

# %%
#Wordcloud 
get_wordcloud(method = 'NMF', model = nmf_model, num_topics = NUM_TOPICS)

# %%
# sentences_chart(ldamodel=nmf_model, corpus=corpus, start = 0, end = 16)
# Plot_topic_dist(ldamodel= nmf_model, num_topics = NUM_TOPICS, corpus = corpus)
# tsne_plot(ldamodel = nmf_model, corpus = corpus,num_topics = NUM_TOPICS , Keep_well_separated_pcnt = 0.30)

# %%
pyldavis_plot(model = nmf_model ,corpus = corpus, mds = "mmds") #,  mds = "tsne"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-b695f86e9afa> in <module>
# ----> 1 pyldavis_plot(model = nmf_model ,corpus = corpus, mds = "mmds") #,  mds = "tsne"
#
# ~\Documents\GitHub\MMAI891_project\LDA\LDA_model.py in pyldavis_plot(model, corpus, mds)
#     337     pyLDAvis.enable_notebook()
#     338     vis = pyLDAvis.gensim.prepare(model, corpus, dictionary=model.id2word, mds=mds)
# --> 339     return vis
#     340
#     341
#
# ~\anaconda3\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     116     See `pyLDAvis.prepare` for **kwargs.
#     117     """
# --> 118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     119     return vis_prepare(**opts)
#
# ~\anaconda3\lib\site-packages\pyLDAvis\gensim.py in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      46           gamma = topic_model.inference(corpus)
#      47       else:
# ---> 48           gamma, _ = topic_model.inference(corpus)
#      49       doc_topic_dists = gamma / gamma.sum(axis=1)[:, None]
#      50    else:
#
# AttributeError: 'Nmf' object has no attribute 'inference'

# %%
pyldavis_plot(model = nmf_model ,corpus = corpus, mds = "tsne")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-4f69902b69dc> in <module>
# ----> 1 pyldavis_plot(model = nmf_model ,corpus = corpus, mds = "tsne")
#
# ~\Documents\GitHub\MMAI891_project\LDA\LDA_model.py in pyldavis_plot(model, corpus, mds)
#     337     pyLDAvis.enable_notebook()
#     338     vis = pyLDAvis.gensim.prepare(model, corpus, dictionary=model.id2word, mds=mds)
# --> 339     return vis
#     340
#     341
#
# ~\anaconda3\lib\site-packages\pyLDAvis\gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     116     See `pyLDAvis.prepare` for **kwargs.
#     117     """
# --> 118     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     119     return vis_prepare(**opts)
#
# ~\anaconda3\lib\site-packages\pyLDAvis\gensim.py in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      46           gamma = topic_model.inference(corpus)
#      47       else:
# ---> 48           gamma, _ = topic_model.inference(corpus)
#      49       doc_topic_dists = gamma / gamma.sum(axis=1)[:, None]
#      50    else:
#
# AttributeError: 'Nmf' object has no attribute 'inference'

# %%
top3_topics = top3_topics_per_document(model = nmf_model, corpus = corpus)

org_data = read_data_meta(in_dir = IN_DIR, filename = FILENAME, text_col = TEXT_COL , 
                 renamed_text_col = RENAMED_TEXT_COL, text_language = LANGUAGE , other_cols = cols)

assert top3_topics.shape[0] == data.shape[0] == org_data.shape[0]

merged = pd.concat([org_data, df_dominant_topic, top3_topics.loc[:, ['Second_Topic', 'Third_Topic']]], axis=1 , ignore_index = False)
merged['Topic_final'].value_counts()

# %%
# merged.to_csv(os.path.join(out_dir, 'df_with_topics_dissatisfaction_reason.csv')

# %%
#see 20 samples for each class

for i in [5,4,8,3,13,10, 99]: 
    print(f'Some examples for topic {i}')
    print('')
    
    samples = merged.loc[merged['Topic_final'] == i , ['Topic_Perc_Contrib','dissatisfaction_reason']].sort_values(by=['Topic_Perc_Contrib'] , ascending=False).head(20)
    print(samples['dissatisfaction_reason'].values)
    print(" ****************")
